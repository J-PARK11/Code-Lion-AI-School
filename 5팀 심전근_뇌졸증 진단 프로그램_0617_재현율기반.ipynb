# %% [markdown]
# # mini5. 중간 프로젝트
# ## 5팀 : 심전근 뇌졸증 진단 프로그램
# 1. Heart Failure Prediction Dataset
# 데이터 출처: https://www.kaggle.com/datasets/fedesoriano/heart-failure-prediction
# 데이터 이름 : 'Healthcare-Stroke.csv'
# 데이터 포맷 : (row, col)
# 메타데이터 :
#     - id : 고유 식별자
#     - gender : 환자의 성별
#     - age : 환자의 연령
#     - hypertension : 환자가 고혈압이 아닌 경우 0, 고혈압인 경우 1
#     - heart_parament : 환자가 심장 질환이 없는 경우 0, 환자가 심장 질환이 있는 경우 1
#     - ever_married : 결혼한 적이 있는가 "아니오" 또는 "예"
#     - work_type : "Children", "Govt_jov", "Never_worked", "Private" 또는 "Self-employed"
#     - Residence_type : "Rural" or "Urban”
#     - avg_glucose_level : 혈중 평균 포도당 수준
#     - bmi : 체질량지수
#     - smoking_status : "formerly smoked", "never smoked", "smokes" or "Unknown"
#     - stroke : 뇌졸중이 있는 경우 1, 뇌졸중이 아닌 경우 0
#     - 참고 : smoking_status의 Unknown은 이 환자에 대한 정보를 사용할 수 없음을 의미한다.
#
#
# 2. Stroke Prediction Dataset
# 데이터 출처: https://www.kaggle.com/datasets/fedesoriano/stroke-prediction-dataset
# 데이터 이름 : 'Healthcare-Heart.csv'
# 데이터 포맷 : (row, col)
# 메타데이터 :
#     - Age : 환자의 나이
#     - Sex : 환자의 성별
#     - ChestPainType : 흉통 유형
#         TA : 일반 협심증,  ATA : 비정형 협심증,  NAP : 비혈관 통증,  ASY : 무증상
#     - RestingBP : 휴면혈압[mmHg]
#     - Cholesterol : 혈청 콜레스테롤 [mm/dl]
#     - FastingBS : 금식혈당
#         1 : 금식인 경우BS > 120 mg/dl
#         0 : 그렇지 않은 경우
#     - RestingECG : 심전도 결과
#         정상 : 정상
#         ST : ST-T파 이상(T파 반전 및/또는 ST 상승 또는 0.05mV 이상 하강)
#         LVH : Estes의 기준에 의해 발생가능하거나 확실한 좌심실 비대
#     - MaxHR : 달성된 최대 심박수 (60 ~ 202)
#     - ExerciseAngina : 운동으로 인한 협심증 Y/N
#     - Oldpeak : 이전 피크 = ST [저하 상태에서 측정된 숫자 값]
#     - ST_Slope : 피크 연습 ST 세그먼트의 기울기 [위: 상향, 평탄: 하향: 하향]
#     - HeartDisease : 1 심장 질환,  0 정상

# %% [markdown]
# ## 0. 환경설정

# %% [markdown]
# ### 라이브러리 호출

# %%
# 라이브러리 호출
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go

from imblearn.over_sampling import SMOTE

# 한글 폰트 패치.
matplotlib.rcParams['font.family']='Malgun Gothic'
matplotlib.rcParams['axes.unicode_minus'] = False  

# 그래프에 retina display 적용
# %config InlineBackend.figure_format = 'retina'

# ggplot style skima
plt.style.use("ggplot")

# seaborn plot style definition
sns.set_style("whitegrid")
sns.set_context("talk")

# 경고문 처리
import warnings
warnings.filterwarnings('ignore')

# Sckit-Learn Module Import
from sklearn.preprocessing import StandardScaler, MinMaxScaler, LabelEncoder, OneHotEncoder
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import plot_tree
from sklearn.metrics import confusion_matrix, precision_score, recall_score, accuracy_score, f1_score
from sklearn.metrics import precision_recall_curve, roc_auc_score, roc_curve, plot_roc_curve

from xgboost import XGBClassifier, plot_importance

# %% [markdown]
# ### 시각화 한글 폰트 설정

# %%
import platform

def get_font_family():
    system_name = platform.system()

    if system_name == "Darwin" :
        font_family = "AppleGothic"
    elif system_name == "Windows":
        font_family = "Malgun Gothic"
    else:
        # !apt-get install fonts-nanum -qq  > /dev/null
        # !fc-cache -fv

        import matplotlib as mpl
        mpl.font_manager._rebuild()
        findfont = mpl.font_manager.fontManager.findfont
        mpl.font_manager.findfont = findfont
        mpl.backends.backend_agg.findfont = findfont
        
        font_family = "NanumBarunGothic"
    return font_family

# %config InlineBackend.figure_format = 'retina'

plt.rc("font", family=get_font_family())
plt.rc("axes", unicode_minus=False)

get_font_family()
# Out:
# 'Malgun Gothic'

# %% [markdown]
# ### 그래프 색상 그라데이션 설정

# %%
def gradientbars(bars,cmap):
    grad = np.expand_dims(np.linspace(0,1,256),0).T
    ax = bars[0].axes 
    lim = ax.get_xlim()+ax.get_ylim() 
    for bar in bars:
        bar.set_facecolor("none") 
        x,y = bar.get_xy() 
        w, h = bar.get_width(), bar.get_height() 
        ax.imshow(grad, extent=[x,x+w,y+h,y], cmap = cmap, aspect="auto",\
                   vmin=-0.5, vmax=2) 
    ax.axis(lim)

# %% [markdown]
# ### 사용자 함수 정의

# %%
# 여러 분류 지표 출력
def get_clf_eval(y_test,pred):
    cf = confusion_matrix(y_test,pred)
    acc = accuracy_score(y_test,pred)
    pre = precision_score(y_test,pred)
    rec = recall_score(y_test,pred)
    f1 = f1_score(y_test,pred)
    
    print(cf)
    print('정확도 :{0:.4f}, 정밀도 :{1:.4f}, 재현율 :{2:.4f}, F1 :{3:.4f}'.format(acc,pre,rec,f1))
#     return [acc, pre, rec, f1]

# 정확도 재현율 곡선
def precision_recall_curve_plot(y_test,pred_proba):
    precisions, recalls, thresholds = precision_recall_curve(y_test, pred_proba)
    
    plt.figure(figsize=(8,6))
    threshold_boundary = thresholds.shape[0]
    plt.plot(thresholds, precisions[0:threshold_boundary], linestyle='--', label='precision')
    plt.plot(thresholds, recalls[0:threshold_boundary], label='recall')
    
    start,end = plt.xlim()
    plt.xticks(np.round(np.arange(start,end,0.1),2))
    plt.xlabel('Threshold value')
    plt.ylabel('Precision and Recall')
    plt.legend()
    plt.grid(True)
    plt.show()
    
# ROC 곡선 
def roc_curve_plot(y_test, pred_proba):
    fprs, tprs, thresholds = roc_curve(y_test, pred_proba)
    
    plt.figure(figsize=(8,6))
    plt.plot(fprs, tprs, label='ROC')
    plt.plot([0,1],[0,1],linestyle='--', label='Random', color='k')
    
    start, end = plt.xlim()
    plt.xticks(np.round(np.arange(start,end,0.1),2))
    plt.xlim(0,1)
    plt.ylim(0,1)
    plt.xlabel('FPR(1 - Sensitivity)')
    plt.ylabel('TPR(Recall)')
    plt.legend()
    plt.show()
    
# 상관관계 히트맵 함수
def corr_plot(data, cmap, width, height, title):
    corr = data.corr()
    mask = np.triu(np.ones_like(corr))

    plt.figure(figsize=(width, height))
    sns.heatmap(corr, annot=True, cmap=cmap, mask=mask, vmin=-1, vmax=1, fmt=".2f")
    plt.title(title, fontsize=20)
    plt.show()
    

# 혼동행렬 시각화 함수
def plot_confusion_matrix(cm, class_names, figsize=(8, 8)):
    cm = cm.numpy()
    figure = plt.figure(figsize=figsize)
    plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
    plt.title("Confusion matrix")
    plt.colorbar()
    tick_marks = np.arange(len(class_names))
    plt.xticks(tick_marks, class_names)
    plt.yticks(tick_marks, class_names)
    
    for i, j in product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j], horizontalalignment="center")
        
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    return figure

# %% [markdown]
# ## 1. 데이터 로드
# ### Healthcare-Stroke.csv (row, col)

# %%
# Data Load
def data_load(path, file):
    df = pd.read_csv(f"{path}{file}", sep=",")
    return df

path = 'data/'
file = 'Healthcare-Stroke.csv'

# %%
df = data_load(path, file)
print('df.shape :',df.shape)
df.head()
# Out:
# df.shape : (5110, 12)
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
df['stroke'].value_counts()
# Out:
# 0    4861
# 1     249
# Name: stroke, dtype: int64

# %%
# data information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5110 non-null   int64
#  1   gender             5110 non-null   object
#  2   age                5110 non-null   float64
#  3   hypertension       5110 non-null   int64
#  4   heart_disease      5110 non-null   int64
#  5   ever_married       5110 non-null   object
#  6   work_type          5110 non-null   object
#  7   Residence_type     5110 non-null   object
#  8   avg_glucose_level  5110 non-null   float64
#  9   bmi                4909 non-null   float64
#  10  smoking_status     5110 non-null   object
#  11  stroke             5110 non-null   int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 479.2+ KB

# %%
# data describe
df.describe()
# Out:
#                  id          age  hypertension  heart_disease  \
# count   5110.000000  5110.000000   5110.000000    5110.000000
# mean   36517.829354    43.226614      0.097456       0.054012
# std    21161.721625    22.612647      0.296607       0.226063
# min       67.000000     0.080000      0.000000       0.000000
# 25%    17741.250000    25.000000      0.000000       0.000000
# 50%    36932.000000    45.000000      0.000000       0.000000
# 75%    54682.000000    61.000000      0.000000       0.000000
# max    72940.000000    82.000000      1.000000       1.000000
#
#        avg_glucose_level          bmi       stroke
# count        5110.000000  4909.000000  5110.000000
# mean          106.147677    28.893237     0.048728
# std            45.283560     7.854067     0.215320
# min            55.120000    10.300000     0.000000
# 25%            77.245000    23.500000     0.000000
# 50%            91.885000    28.100000     0.000000
# 75%           114.090000    33.100000     0.000000
# max           271.740000    97.600000     1.000000

# %% [markdown]
# ## 2. 데이터 전처리 & EDA

# %%
# 의미없는 'ID'특성 제거
df = df[df.columns.difference(['id'])]
df.shape
# Out:
# (5110, 11)

# %% [markdown]
# ### LabelEncoding

# %%
# LabelEncoding
cat_list = ['gender','ever_married','work_type','Residence_type','smoking_status']
for cat in cat_list:
    l_encoder = LabelEncoder()
    l_encoder.fit(df[cat])
    labels = l_encoder.transform(df[cat])
    df[cat] = labels

    print(cat,':',l_encoder.classes_)
    print(cat,'encoded :',np.unique(labels),'\n')
# Out:
# gender : ['Female' 'Male' 'Other']
# gender encoded : [0 1 2]
#
# ever_married : ['No' 'Yes']
# ever_married encoded : [0 1]
#
# work_type : ['Govt_job' 'Never_worked' 'Private' 'Self-employed' 'children']
# work_type encoded : [0 1 2 3 4]
#
# Residence_type : ['Rural' 'Urban']
# Residence_type encoded : [0 1]
#
# smoking_status : ['Unknown' 'formerly smoked' 'never smoked' 'smokes']
# smoking_status encoded : [0 1 2 3]

# %% [markdown]
# ### MissingValue Processing

# %%
# gender = 2로 표기되어 있는 사람은 성별을 알 수 없으므로 제거.
df[df['gender'] == 2]
# Out:
#       Residence_type   age  avg_glucose_level   bmi  ever_married  gender  \
# 3116               0  26.0             143.33  22.4             0       2
#
#       heart_disease  hypertension  smoking_status  stroke  work_type
# 3116              0             0               1       0          2

# %%
df.drop(index = df[df['gender'] == 2].index, inplace=True)

# %%
# bmi 칼럼의 nan값들을 평균값으로 대치
df['bmi'].fillna(df['bmi'].mean(), axis=0,inplace=True)

# %% [markdown]
# ### Outlier Processing

# %%
plt.title("'avg_glucose_lebel' distribution")
sns.boxplot(df['avg_glucose_level'])
plt.show()

# %%
plt.title("'bmi' distribution")
sns.boxplot(df['bmi'])
plt.show()

# %%
# bmi 칼럼의 상위 4 개의 이상치에 대해 최대값으로 대치
df.loc[df['bmi'].sort_values(ascending=False)[:4].index,'bmi'] = df['bmi'].sort_values(ascending=False)[:5].values[-1]

# %% [markdown]
# ### StandardScaler, Log Transformation

# %%
# Histogram
df.hist(figsize=(12,14),bins=50)
plt.show()

# %%
# 로그 변환 to ['bmi', 'avg_glucose_level']
df[['bmi', 'avg_glucose_level']] = np.log1p(df[['bmi', 'avg_glucose_level']])

# %%
# Histogram
df.hist(figsize=(12,14),bins=50)
plt.show()

# %%
corr_plot(df, 'coolwarm',12, 12, 'Stroke Dataset Correlation')

# %%
# 표준화
scaler = StandardScaler()
X_scaled = scaler.fit_transform(df.drop('stroke',axis=1))
print('X_scaled.shape :',X_scaled.shape)
# Out:
# X_scaled.shape : (5109, 10)

# %% [markdown]
# ## 4. ML Model Train

# %%
print('df.shape :',df.shape)
df.head()
# Out:
# df.shape : (5109, 11)
#    Residence_type   age  avg_glucose_level       bmi  ever_married  gender  \
# 0               1  67.0           5.436731  3.627004             1       1
# 1               0  61.0           5.314240  3.397677             1       0
# 2               0  80.0           4.672081  3.511545             1       1
# 3               1  49.0           5.148831  3.566712             1       0
# 4               0  79.0           5.165471  3.218876             1       0
#
#    heart_disease  hypertension  smoking_status  stroke  work_type
# 0              1             0               1       1          2
# 1              0             0               2       1          3
# 2              1             0               2       1          2
# 3              0             0               3       1          2
# 4              0             1               2       1          3

# %% [markdown]
# ### 데이터 분할

# %%
X_data = X_scaled
y_data = df['stroke']
print('X_data.shape :',X_data.shape)
print('y_data.shape :',y_data.shape,'\n')

X_train, X_test, y_train, y_test = train_test_split(X_data, y_data, test_size=0.2, stratify = y_data,
                                                   shuffle=True, random_state=42)

print('X_train.shape :',X_train.shape)
print('y_train.shape :',y_train.shape)
print('X_test.shape :',X_test.shape)
print('y_Test.shape :',y_test.shape)
# Out:
# X_data.shape : (5109, 10)
# y_data.shape : (5109,)
#
# X_train.shape : (4087, 10)
# y_train.shape : (4087,)
# X_test.shape : (1022, 10)
# y_Test.shape : (1022,)

# %% [markdown]
# ### 데이터 오버샘플링

# %%
sm = SMOTE(sampling_strategy = 'auto', random_state = 42)
X_smote, y_smote = sm.fit_resample(X_train, y_train)
print('X_smote.shape :',X_smote.shape)
print('y_smote.shape :',y_smote.shape)
# Out:
# X_smote.shape : (7776, 10)
# y_smote.shape : (7776,)

# %%
y_smote.value_counts(normalize=True)
# Out:
# 0    0.5
# 1    0.5
# Name: stroke, dtype: float64

# %% [markdown]
# ### GridSearchCV

# %%
# 하이퍼파라미터 튜닝
model = XGBClassifier(n_estimators=400, learning_rate=0.1, max_depth = 3)
evals = [(X_test,y_test)]
param_grid = {
    'learning_rate':[0.01,0.05,0.1],
    'n_estimators':[100,200,300,400],
}

grid_cv = GridSearchCV(model, cv=3, refit=True, param_grid=param_grid, scoring='recall')
grid_cv.fit(X_smote, y_smote, early_stopping_rounds=50, eval_metric='logloss', eval_set=evals, verbose=True)
# Out:
# [0]	validation_0-logloss:0.68884
# [1]	validation_0-logloss:0.68463
# [2]	validation_0-logloss:0.68050
# [3]	validation_0-logloss:0.67648
# [4]	validation_0-logloss:0.67253
# [5]	validation_0-logloss:0.66866
# [6]	validation_0-logloss:0.66486
# [7]	validation_0-logloss:0.66123
# [8]	validation_0-logloss:0.65760
# [9]	validation_0-logloss:0.65409
# [10]	validation_0-logloss:0.65062
# [11]	validation_0-logloss:0.64723
# [12]	validation_0-logloss:0.64391
# [13]	validation_0-logloss:0.64072
# [14]	validation_0-logloss:0.63754
# [15]	validation_0-logloss:0.63442
# [16]	validation_0-logloss:0.63140
# [17]	validation_0-logloss:0.62840
# [18]	validation_0-logloss:0.62548
# [19]	validation_0-logloss:0.62264
# [20]	validation_0-logloss:0.61982
# [21]	validation_0-logloss:0.61714
# [22]	validation_0-logloss:0.61446
# [23]	validation_0-logloss:0.61183
# [24]	validation_0-logloss:0.60927
# [25]	validation_0-logloss:0.60663
# [26]	validation_0-logloss:0.60414
# [27]	validation_0-logloss:0.60170
# [28]	validation_0-logloss:0.59932
# [29]	validation_0-logloss:0.59702
# [30]	validation_0-logloss:0.59474
# [31]	validation_0-logloss:0.59235
# [32]	validation_0-logloss:0.59015
# [33]	validation_0-logloss:0.58797
# [34]	validation_0-logloss:0.58584
# [35]	validation_0-logloss:0.58376
# [36]	validation_0-logloss:0.58176
# [37]	validation_0-logloss:0.57974
# [38]	validation_0-logloss:0.57774
# [39]	validation_0-logloss:0.57581
# [40]	validation_0-logloss:0.57396
# [41]	validation_0-logloss:0.57209
# [42]	validation_0-logloss:0.57028
# [43]	validation_0-logloss:0.56834
# [44]	validation_0-logloss:0.56647
# [45]	validation_0-logloss:0.56475
# [46]	validation_0-logloss:0.56302
# [47]	validation_0-logloss:0.56139
# [48]	validation_0-logloss:0.55964
# [49]	validation_0-logloss:0.55788
# [50]	validation_0-logloss:0.55630
# [51]	validation_0-logloss:0.55472
# [52]	validation_0-logloss:0.55309
# [53]	validation_0-logloss:0.55158
# [54]	validation_0-logloss:0.55011
# [55]	validation_0-logloss:0.54867
# [56]	validation_0-logloss:0.54726
# [57]	validation_0-logloss:0.54587
# [58]	validation_0-logloss:0.54452
# [59]	validation_0-logloss:0.54312
# [60]	validation_0-logloss:0.54180
# [61]	validation_0-logloss:0.54053
# [62]	validation_0-logloss:0.53922
# [63]	validation_0-logloss:0.53797
# [64]	validation_0-logloss:0.53675
# [65]	validation_0-logloss:0.53554
# [66]	validation_0-logloss:0.53437
# [67]	validation_0-logloss:0.53320
# [68]	validation_0-logloss:0.53155
# [69]	validation_0-logloss:0.53036
# [70]	validation_0-logloss:0.52926
# [71]	validation_0-logloss:0.52818
# [72]	validation_0-logloss:0.52712
# [73]	validation_0-logloss:0.52555
# [74]	validation_0-logloss:0.52447
# [75]	validation_0-logloss:0.52291
# [76]	validation_0-logloss:0.52191
# [77]	validation_0-logloss:0.52044
# [78]	validation_0-logloss:0.51894
# [79]	validation_0-logloss:0.51796
# [80]	validation_0-logloss:0.51686
# [81]	validation_0-logloss:0.51571
# [82]	validation_0-logloss:0.51469
# [83]	validation_0-logloss:0.51353
# [84]	validation_0-logloss:0.51211
# [85]	validation_0-logloss:0.51075
# [86]	validation_0-logloss:0.50964
# [87]	validation_0-logloss:0.50869
# [88]	validation_0-logloss:0.50762
# [89]	validation_0-logloss:0.50676
# [90]	validation_0-logloss:0.50545
# [91]	validation_0-logloss:0.50441
# [92]	validation_0-logloss:0.50351
# [93]	validation_0-logloss:0.50251
# [94]	validation_0-logloss:0.50122
# [95]	validation_0-logloss:0.49996
# [96]	validation_0-logloss:0.49900
# [97]	validation_0-logloss:0.49814
# [98]	validation_0-logloss:0.49721
# [99]	validation_0-logloss:0.49599
# [0]	validation_0-logloss:0.68886
# [1]	validation_0-logloss:0.68468
# [2]	validation_0-logloss:0.68059
# [3]	validation_0-logloss:0.67662
# [4]	validation_0-logloss:0.67271
# [5]	validation_0-logloss:0.66890
# [6]	validation_0-logloss:0.66517
# [7]	validation_0-logloss:0.66151
# [8]	validation_0-logloss:0.65799
# [9]	validation_0-logloss:0.65450
# [10]	validation_0-logloss:0.65113
# [11]	validation_0-logloss:0.64779
# [12]	validation_0-logloss:0.64426
# [13]	validation_0-logloss:0.64109
# [14]	validation_0-logloss:0.63790
# [15]	validation_0-logloss:0.63457
# [16]	validation_0-logloss:0.63155
# [17]	validation_0-logloss:0.62855
# [18]	validation_0-logloss:0.62540
# [19]	validation_0-logloss:0.62262
# [20]	validation_0-logloss:0.61988
# [21]	validation_0-logloss:0.61718
# [22]	validation_0-logloss:0.61446
# [23]	validation_0-logloss:0.61178
# [24]	validation_0-logloss:0.60925
# [25]	validation_0-logloss:0.60680
# [26]	validation_0-logloss:0.60437
# [27]	validation_0-logloss:0.60189
# [28]	validation_0-logloss:0.59961
# [29]	validation_0-logloss:0.59722
# [30]	validation_0-logloss:0.59498
# [31]	validation_0-logloss:0.59271
# [32]	validation_0-logloss:0.59052
# [33]	validation_0-logloss:0.58836
# [34]	validation_0-logloss:0.58615
# [35]	validation_0-logloss:0.58404
# [36]	validation_0-logloss:0.58204
# [37]	validation_0-logloss:0.57999
# [38]	validation_0-logloss:0.57811
# [39]	validation_0-logloss:0.57604
# [40]	validation_0-logloss:0.57416
# [41]	validation_0-logloss:0.57230
# [42]	validation_0-logloss:0.57050
# [43]	validation_0-logloss:0.56868
# [44]	validation_0-logloss:0.56677
# [45]	validation_0-logloss:0.56501
# [46]	validation_0-logloss:0.56335
# [47]	validation_0-logloss:0.56167
# [48]	validation_0-logloss:0.55999
# [49]	validation_0-logloss:0.55823
# [50]	validation_0-logloss:0.55667
# [51]	validation_0-logloss:0.55503
# [52]	validation_0-logloss:0.55348
# [53]	validation_0-logloss:0.55195
# [54]	validation_0-logloss:0.55002
# [55]	validation_0-logloss:0.54858
# [56]	validation_0-logloss:0.54717
# [57]	validation_0-logloss:0.54579
# [58]	validation_0-logloss:0.54443
# [59]	validation_0-logloss:0.54310
# [60]	validation_0-logloss:0.54179
# [61]	validation_0-logloss:0.54053
# [62]	validation_0-logloss:0.53930
# [63]	validation_0-logloss:0.53806
# [64]	validation_0-logloss:0.53686
# [65]	validation_0-logloss:0.53564
# [66]	validation_0-logloss:0.53447
# [67]	validation_0-logloss:0.53327
# [68]	validation_0-logloss:0.53209
# [69]	validation_0-logloss:0.53102
# [70]	validation_0-logloss:0.52989
# [71]	validation_0-logloss:0.52884
# [72]	validation_0-logloss:0.52774
# [73]	validation_0-logloss:0.52670
# [74]	validation_0-logloss:0.52565
# [75]	validation_0-logloss:0.52458
# [76]	validation_0-logloss:0.52360
# [77]	validation_0-logloss:0.52256
# [78]	validation_0-logloss:0.52153
# [79]	validation_0-logloss:0.52012
# [80]	validation_0-logloss:0.51924
# [81]	validation_0-logloss:0.51787
# [82]	validation_0-logloss:0.51690
# [83]	validation_0-logloss:0.51556
# [84]	validation_0-logloss:0.51471
# [85]	validation_0-logloss:0.51340
# [86]	validation_0-logloss:0.51248
# [87]	validation_0-logloss:0.51120
# [88]	validation_0-logloss:0.50994
# [89]	validation_0-logloss:0.50907
# [90]	validation_0-logloss:0.50824
# [91]	validation_0-logloss:0.50702
# [92]	validation_0-logloss:0.50579
# [93]	validation_0-logloss:0.50494
# [94]	validation_0-logloss:0.50420
# [95]	validation_0-logloss:0.50303
# [96]	validation_0-logloss:0.50218
# [97]	validation_0-logloss:0.50103
# [98]	validation_0-logloss:0.50026
# [99]	validation_0-logloss:0.49912
# [0]	validation_0-logloss:0.68887
# [1]	validation_0-logloss:0.68469
# [2]	validation_0-logloss:0.68061
# [3]	validation_0-logloss:0.67662
# [4]	validation_0-logloss:0.67269
# [5]	validation_0-logloss:0.66889
# [6]	validation_0-logloss:0.66516
# [7]	validation_0-logloss:0.66148
# [8]	validation_0-logloss:0.65793
# [9]	validation_0-logloss:0.65441
# [10]	validation_0-logloss:0.65099
# [11]	validation_0-logloss:0.64770
# [12]	validation_0-logloss:0.64440
# [13]	validation_0-logloss:0.64125
# [14]	validation_0-logloss:0.63814
# [15]	validation_0-logloss:0.63510
# [16]	validation_0-logloss:0.63208
# [17]	validation_0-logloss:0.62919
# [18]	validation_0-logloss:0.62633
# [19]	validation_0-logloss:0.62350
# [20]	validation_0-logloss:0.62077
# [21]	validation_0-logloss:0.61806
# [22]	validation_0-logloss:0.61539
# [23]	validation_0-logloss:0.61278
# [24]	validation_0-logloss:0.61013
# [25]	validation_0-logloss:0.60767
# [26]	validation_0-logloss:0.60520
# [27]	validation_0-logloss:0.60277
# [28]	validation_0-logloss:0.60041
# [29]	validation_0-logloss:0.59808
# [30]	validation_0-logloss:0.59579
# [31]	validation_0-logloss:0.59354
# [32]	validation_0-logloss:0.59132
# [33]	validation_0-logloss:0.58918
# [34]	validation_0-logloss:0.58706
# [35]	validation_0-logloss:0.58497
# [36]	validation_0-logloss:0.58292
# [37]	validation_0-logloss:0.58091
# [38]	validation_0-logloss:0.57893
# [39]	validation_0-logloss:0.57706
# [40]	validation_0-logloss:0.57518
# [41]	validation_0-logloss:0.57330
# [42]	validation_0-logloss:0.57146
# [43]	validation_0-logloss:0.56966
# [44]	validation_0-logloss:0.56788
# [45]	validation_0-logloss:0.56614
# [46]	validation_0-logloss:0.56444
# [47]	validation_0-logloss:0.56275
# [48]	validation_0-logloss:0.56113
# [49]	validation_0-logloss:0.55951
# [50]	validation_0-logloss:0.55797
# [51]	validation_0-logloss:0.55634
# [52]	validation_0-logloss:0.55481
# [53]	validation_0-logloss:0.55324
# [54]	validation_0-logloss:0.55174
# [55]	validation_0-logloss:0.55021
# [56]	validation_0-logloss:0.54878
# [57]	validation_0-logloss:0.54739
# [58]	validation_0-logloss:0.54593
# [59]	validation_0-logloss:0.54457
# [60]	validation_0-logloss:0.54316
# [61]	validation_0-logloss:0.54188
# [62]	validation_0-logloss:0.54056
# [63]	validation_0-logloss:0.53922
# [64]	validation_0-logloss:0.53797
# [65]	validation_0-logloss:0.53667
# [66]	validation_0-logloss:0.53546
# [67]	validation_0-logloss:0.53425
# [68]	validation_0-logloss:0.53300
# [69]	validation_0-logloss:0.53192
# [70]	validation_0-logloss:0.53081
# [71]	validation_0-logloss:0.52962
# [72]	validation_0-logloss:0.52851
# [73]	validation_0-logloss:0.52735
# [74]	validation_0-logloss:0.52620
# [75]	validation_0-logloss:0.52510
# [76]	validation_0-logloss:0.52368
# [77]	validation_0-logloss:0.52274
# [78]	validation_0-logloss:0.52136
# [79]	validation_0-logloss:0.52033
# [80]	validation_0-logloss:0.51899
# [81]	validation_0-logloss:0.51804
# [82]	validation_0-logloss:0.51707
# [83]	validation_0-logloss:0.51577
# [84]	validation_0-logloss:0.51450
# [85]	validation_0-logloss:0.51358
# [86]	validation_0-logloss:0.51233
# [87]	validation_0-logloss:0.51148
# [88]	validation_0-logloss:0.51059
# [89]	validation_0-logloss:0.50938
# [90]	validation_0-logloss:0.50857
# [91]	validation_0-logloss:0.50775
# [92]	validation_0-logloss:0.50687
# [93]	validation_0-logloss:0.50609
# [94]	validation_0-logloss:0.50524
# [95]	validation_0-logloss:0.50411
# [96]	validation_0-logloss:0.50330
# [97]	validation_0-logloss:0.50219
# [98]	validation_0-logloss:0.50149
# [99]	validation_0-logloss:0.50070
# [0]	validation_0-logloss:0.68884
# [1]	validation_0-logloss:0.68463
# [2]	validation_0-logloss:0.68050
# [3]	validation_0-logloss:0.67648
# [4]	validation_0-logloss:0.67253
# [5]	validation_0-logloss:0.66866
# [6]	validation_0-logloss:0.66486
# [7]	validation_0-logloss:0.66123
# [8]	validation_0-logloss:0.65760
# [9]	validation_0-logloss:0.65409
# [10]	validation_0-logloss:0.65062
# [11]	validation_0-logloss:0.64723
# [12]	validation_0-logloss:0.64391
# [13]	validation_0-logloss:0.64072
# [14]	validation_0-logloss:0.63754
# [15]	validation_0-logloss:0.63442
# [16]	validation_0-logloss:0.63140
# [17]	validation_0-logloss:0.62840
# [18]	validation_0-logloss:0.62548
# [19]	validation_0-logloss:0.62264
# [20]	validation_0-logloss:0.61982
# [21]	validation_0-logloss:0.61714
# [22]	validation_0-logloss:0.61446
# [23]	validation_0-logloss:0.61183
# [24]	validation_0-logloss:0.60927
# [25]	validation_0-logloss:0.60663
# [26]	validation_0-logloss:0.60414
# [27]	validation_0-logloss:0.60170
# [28]	validation_0-logloss:0.59932
# [29]	validation_0-logloss:0.59702
# [30]	validation_0-logloss:0.59474
# [31]	validation_0-logloss:0.59235
# [32]	validation_0-logloss:0.59015
# [33]	validation_0-logloss:0.58797
# [34]	validation_0-logloss:0.58584
# [35]	validation_0-logloss:0.58376
# [36]	validation_0-logloss:0.58176
# [37]	validation_0-logloss:0.57974
# [38]	validation_0-logloss:0.57774
# [39]	validation_0-logloss:0.57581
# [40]	validation_0-logloss:0.57396
# [41]	validation_0-logloss:0.57209
# [42]	validation_0-logloss:0.57028
# [43]	validation_0-logloss:0.56834
# [44]	validation_0-logloss:0.56647
# [45]	validation_0-logloss:0.56475
# [46]	validation_0-logloss:0.56302
# [47]	validation_0-logloss:0.56139
# [48]	validation_0-logloss:0.55964
# [49]	validation_0-logloss:0.55788
# [50]	validation_0-logloss:0.55630
# [51]	validation_0-logloss:0.55472
# [52]	validation_0-logloss:0.55309
# [53]	validation_0-logloss:0.55158
# [54]	validation_0-logloss:0.55011
# [55]	validation_0-logloss:0.54867
# [56]	validation_0-logloss:0.54726
# [57]	validation_0-logloss:0.54587
# [58]	validation_0-logloss:0.54452
# [59]	validation_0-logloss:0.54312
# [60]	validation_0-logloss:0.54180
# [61]	validation_0-logloss:0.54053
# [62]	validation_0-logloss:0.53922
# [63]	validation_0-logloss:0.53797
# [64]	validation_0-logloss:0.53675
# [65]	validation_0-logloss:0.53554
# [66]	validation_0-logloss:0.53437
# [67]	validation_0-logloss:0.53320
# [68]	validation_0-logloss:0.53155
# [69]	validation_0-logloss:0.53036
# [70]	validation_0-logloss:0.52926
# [71]	validation_0-logloss:0.52818
# [72]	validation_0-logloss:0.52712
# [73]	validation_0-logloss:0.52555
# [74]	validation_0-logloss:0.52447
# [75]	validation_0-logloss:0.52291
# [76]	validation_0-logloss:0.52191
# [77]	validation_0-logloss:0.52044
# [78]	validation_0-logloss:0.51894
# [79]	validation_0-logloss:0.51796
# [80]	validation_0-logloss:0.51686
# [81]	validation_0-logloss:0.51571
# [82]	validation_0-logloss:0.51469
# [83]	validation_0-logloss:0.51353
# [84]	validation_0-logloss:0.51211
# [85]	validation_0-logloss:0.51075
# [86]	validation_0-logloss:0.50964
# [87]	validation_0-logloss:0.50869
# [88]	validation_0-logloss:0.50762
# [89]	validation_0-logloss:0.50676
# [90]	validation_0-logloss:0.50545
# [91]	validation_0-logloss:0.50441
# [92]	validation_0-logloss:0.50351
# [93]	validation_0-logloss:0.50251
# [94]	validation_0-logloss:0.50122
# [95]	validation_0-logloss:0.49996
# [96]	validation_0-logloss:0.49900
# [97]	validation_0-logloss:0.49814
# [98]	validation_0-logloss:0.49721
# [99]	validation_0-logloss:0.49599
# [100]	validation_0-logloss:0.49508
# [101]	validation_0-logloss:0.49389
# [102]	validation_0-logloss:0.49267
# [103]	validation_0-logloss:0.49197
# [104]	validation_0-logloss:0.49118
# [105]	validation_0-logloss:0.49032
# [106]	validation_0-logloss:0.48946
# [107]	validation_0-logloss:0.48836
# [108]	validation_0-logloss:0.48769
# [109]	validation_0-logloss:0.48698
# [110]	validation_0-logloss:0.48617
# [111]	validation_0-logloss:0.48535
# [112]	validation_0-logloss:0.48429
# [113]	validation_0-logloss:0.48324
# [114]	validation_0-logloss:0.48213
# [115]	validation_0-logloss:0.48157
# [116]	validation_0-logloss:0.48103
# [117]	validation_0-logloss:0.48050
# [118]	validation_0-logloss:0.47998
# [119]	validation_0-logloss:0.47932
# [120]	validation_0-logloss:0.47858
# [121]	validation_0-logloss:0.47805
# [122]	validation_0-logloss:0.47707
# [123]	validation_0-logloss:0.47635
# [124]	validation_0-logloss:0.47573
# [125]	validation_0-logloss:0.47469
# [126]	validation_0-logloss:0.47373
# [127]	validation_0-logloss:0.47328
# [128]	validation_0-logloss:0.47259
# [129]	validation_0-logloss:0.47166
# [130]	validation_0-logloss:0.47107
# [131]	validation_0-logloss:0.47041
# [132]	validation_0-logloss:0.46949
# [133]	validation_0-logloss:0.46907
# [134]	validation_0-logloss:0.46843
# [135]	validation_0-logloss:0.46787
# [136]	validation_0-logloss:0.46690
# [137]	validation_0-logloss:0.46600
# [138]	validation_0-logloss:0.46512
# [139]	validation_0-logloss:0.46417
# [140]	validation_0-logloss:0.46364
# [141]	validation_0-logloss:0.46273
# [142]	validation_0-logloss:0.46181
# [143]	validation_0-logloss:0.46123
# [144]	validation_0-logloss:0.46064
# [145]	validation_0-logloss:0.45980
# [146]	validation_0-logloss:0.45944
# [147]	validation_0-logloss:0.45858
# [148]	validation_0-logloss:0.45803
# [149]	validation_0-logloss:0.45715
# [150]	validation_0-logloss:0.45667
# [151]	validation_0-logloss:0.45581
# [152]	validation_0-logloss:0.45500
# [153]	validation_0-logloss:0.45467
# [154]	validation_0-logloss:0.45413
# [155]	validation_0-logloss:0.45366
# [156]	validation_0-logloss:0.45283
# [157]	validation_0-logloss:0.45204
# [158]	validation_0-logloss:0.45121
# [159]	validation_0-logloss:0.45070
# [160]	validation_0-logloss:0.44988
# [161]	validation_0-logloss:0.44911
# [162]	validation_0-logloss:0.44867
# [163]	validation_0-logloss:0.44825
# [164]	validation_0-logloss:0.44796
# [165]	validation_0-logloss:0.44716
# [166]	validation_0-logloss:0.44667
# [167]	validation_0-logloss:0.44590
# [168]	validation_0-logloss:0.44516
# [169]	validation_0-logloss:0.44474
# [170]	validation_0-logloss:0.44408
# [171]	validation_0-logloss:0.44361
# [172]	validation_0-logloss:0.44323
# [173]	validation_0-logloss:0.44298
# [174]	validation_0-logloss:0.44258
# [175]	validation_0-logloss:0.44194
# [176]	validation_0-logloss:0.44148
# [177]	validation_0-logloss:0.44078
# [178]	validation_0-logloss:0.44006
# [179]	validation_0-logloss:0.43968
# [180]	validation_0-logloss:0.43945
# [181]	validation_0-logloss:0.43883
# [182]	validation_0-logloss:0.43839
# [183]	validation_0-logloss:0.43771
# [184]	validation_0-logloss:0.43702
# [185]	validation_0-logloss:0.43665
# [186]	validation_0-logloss:0.43633
# [187]	validation_0-logloss:0.43590
# [188]	validation_0-logloss:0.43524
# [189]	validation_0-logloss:0.43499
# [190]	validation_0-logloss:0.43467
# [191]	validation_0-logloss:0.43426
# [192]	validation_0-logloss:0.43391
# [193]	validation_0-logloss:0.43363
# [194]	validation_0-logloss:0.43323
# [195]	validation_0-logloss:0.43266
# [196]	validation_0-logloss:0.43227
# [197]	validation_0-logloss:0.43199
# [198]	validation_0-logloss:0.43132
# [199]	validation_0-logloss:0.43107
# [0]	validation_0-logloss:0.68886
# [1]	validation_0-logloss:0.68468
# [2]	validation_0-logloss:0.68059
# [3]	validation_0-logloss:0.67662
# [4]	validation_0-logloss:0.67271
# [5]	validation_0-logloss:0.66890
# [6]	validation_0-logloss:0.66517
# [7]	validation_0-logloss:0.66151
# [8]	validation_0-logloss:0.65799
# [9]	validation_0-logloss:0.65450
# [10]	validation_0-logloss:0.65113
# [11]	validation_0-logloss:0.64779
# [12]	validation_0-logloss:0.64426
# [13]	validation_0-logloss:0.64109
# [14]	validation_0-logloss:0.63790
# [15]	validation_0-logloss:0.63457
# [16]	validation_0-logloss:0.63155
# [17]	validation_0-logloss:0.62855
# [18]	validation_0-logloss:0.62540
# [19]	validation_0-logloss:0.62262
# [20]	validation_0-logloss:0.61988
# [21]	validation_0-logloss:0.61718
# [22]	validation_0-logloss:0.61446
# [23]	validation_0-logloss:0.61178
# [24]	validation_0-logloss:0.60925
# [25]	validation_0-logloss:0.60680
# [26]	validation_0-logloss:0.60437
# [27]	validation_0-logloss:0.60189
# [28]	validation_0-logloss:0.59961
# [29]	validation_0-logloss:0.59722
# [30]	validation_0-logloss:0.59498
# [31]	validation_0-logloss:0.59271
# [32]	validation_0-logloss:0.59052
# [33]	validation_0-logloss:0.58836
# [34]	validation_0-logloss:0.58615
# [35]	validation_0-logloss:0.58404
# [36]	validation_0-logloss:0.58204
# [37]	validation_0-logloss:0.57999
# [38]	validation_0-logloss:0.57811
# [39]	validation_0-logloss:0.57604
# [40]	validation_0-logloss:0.57416
# [41]	validation_0-logloss:0.57230
# [42]	validation_0-logloss:0.57050
# [43]	validation_0-logloss:0.56868
# [44]	validation_0-logloss:0.56677
# [45]	validation_0-logloss:0.56501
# [46]	validation_0-logloss:0.56335
# [47]	validation_0-logloss:0.56167
# [48]	validation_0-logloss:0.55999
# [49]	validation_0-logloss:0.55823
# [50]	validation_0-logloss:0.55667
# [51]	validation_0-logloss:0.55503
# [52]	validation_0-logloss:0.55348
# [53]	validation_0-logloss:0.55195
# [54]	validation_0-logloss:0.55002
# [55]	validation_0-logloss:0.54858
# [56]	validation_0-logloss:0.54717
# [57]	validation_0-logloss:0.54579
# [58]	validation_0-logloss:0.54443
# [59]	validation_0-logloss:0.54310
# [60]	validation_0-logloss:0.54179
# [61]	validation_0-logloss:0.54053
# [62]	validation_0-logloss:0.53930
# [63]	validation_0-logloss:0.53806
# [64]	validation_0-logloss:0.53686
# [65]	validation_0-logloss:0.53564
# [66]	validation_0-logloss:0.53447
# [67]	validation_0-logloss:0.53327
# [68]	validation_0-logloss:0.53209
# [69]	validation_0-logloss:0.53102
# [70]	validation_0-logloss:0.52989
# [71]	validation_0-logloss:0.52884
# [72]	validation_0-logloss:0.52774
# [73]	validation_0-logloss:0.52670
# [74]	validation_0-logloss:0.52565
# [75]	validation_0-logloss:0.52458
# [76]	validation_0-logloss:0.52360
# [77]	validation_0-logloss:0.52256
# [78]	validation_0-logloss:0.52153
# [79]	validation_0-logloss:0.52012
# [80]	validation_0-logloss:0.51924
# [81]	validation_0-logloss:0.51787
# [82]	validation_0-logloss:0.51690
# [83]	validation_0-logloss:0.51556
# [84]	validation_0-logloss:0.51471
# [85]	validation_0-logloss:0.51340
# [86]	validation_0-logloss:0.51248
# [87]	validation_0-logloss:0.51120
# [88]	validation_0-logloss:0.50994
# [89]	validation_0-logloss:0.50907
# [90]	validation_0-logloss:0.50824
# [91]	validation_0-logloss:0.50702
# [92]	validation_0-logloss:0.50579
# [93]	validation_0-logloss:0.50494
# [94]	validation_0-logloss:0.50420
# [95]	validation_0-logloss:0.50303
# [96]	validation_0-logloss:0.50218
# [97]	validation_0-logloss:0.50103
# [98]	validation_0-logloss:0.50026
# [99]	validation_0-logloss:0.49912
# [100]	validation_0-logloss:0.49831
# [101]	validation_0-logloss:0.49753
# [102]	validation_0-logloss:0.49643
# [103]	validation_0-logloss:0.49528
# [104]	validation_0-logloss:0.49467
# [105]	validation_0-logloss:0.49361
# [106]	validation_0-logloss:0.49249
# [107]	validation_0-logloss:0.49185
# [108]	validation_0-logloss:0.49126
# [109]	validation_0-logloss:0.49026
# [110]	validation_0-logloss:0.48956
# [111]	validation_0-logloss:0.48858
# [112]	validation_0-logloss:0.48790
# [113]	validation_0-logloss:0.48729
# [114]	validation_0-logloss:0.48664
# [115]	validation_0-logloss:0.48607
# [116]	validation_0-logloss:0.48512
# [117]	validation_0-logloss:0.48449
# [118]	validation_0-logloss:0.48394
# [119]	validation_0-logloss:0.48303
# [120]	validation_0-logloss:0.48239
# [121]	validation_0-logloss:0.48187
# [122]	validation_0-logloss:0.48127
# [123]	validation_0-logloss:0.48057
# [124]	validation_0-logloss:0.47967
# [125]	validation_0-logloss:0.47899
# [126]	validation_0-logloss:0.47846
# [127]	validation_0-logloss:0.47787
# [128]	validation_0-logloss:0.47722
# [129]	validation_0-logloss:0.47668
# [130]	validation_0-logloss:0.47580
# [131]	validation_0-logloss:0.47522
# [132]	validation_0-logloss:0.47460
# [133]	validation_0-logloss:0.47374
# [134]	validation_0-logloss:0.47313
# [135]	validation_0-logloss:0.47259
# [136]	validation_0-logloss:0.47174
# [137]	validation_0-logloss:0.47131
# [138]	validation_0-logloss:0.47087
# [139]	validation_0-logloss:0.47005
# [140]	validation_0-logloss:0.46964
# [141]	validation_0-logloss:0.46913
# [142]	validation_0-logloss:0.46832
# [143]	validation_0-logloss:0.46786
# [144]	validation_0-logloss:0.46736
# [145]	validation_0-logloss:0.46693
# [146]	validation_0-logloss:0.46616
# [147]	validation_0-logloss:0.46567
# [148]	validation_0-logloss:0.46529
# [149]	validation_0-logloss:0.46480
# [150]	validation_0-logloss:0.46429
# [151]	validation_0-logloss:0.46354
# [152]	validation_0-logloss:0.46315
# [153]	validation_0-logloss:0.46265
# [154]	validation_0-logloss:0.46188
# [155]	validation_0-logloss:0.46139
# [156]	validation_0-logloss:0.46092
# [157]	validation_0-logloss:0.46059
# [158]	validation_0-logloss:0.46010
# [159]	validation_0-logloss:0.45935
# [160]	validation_0-logloss:0.45902
# [161]	validation_0-logloss:0.45855
# [162]	validation_0-logloss:0.45781
# [163]	validation_0-logloss:0.45748
# [164]	validation_0-logloss:0.45704
# [165]	validation_0-logloss:0.45659
# [166]	validation_0-logloss:0.45586
# [167]	validation_0-logloss:0.45541
# [168]	validation_0-logloss:0.45514
# [169]	validation_0-logloss:0.45444
# [170]	validation_0-logloss:0.45402
# [171]	validation_0-logloss:0.45370
# [172]	validation_0-logloss:0.45326
# [173]	validation_0-logloss:0.45298
# [174]	validation_0-logloss:0.45230
# [175]	validation_0-logloss:0.45187
# [176]	validation_0-logloss:0.45162
# [177]	validation_0-logloss:0.45122
# [178]	validation_0-logloss:0.45099
# [179]	validation_0-logloss:0.45030
# [180]	validation_0-logloss:0.44964
# [181]	validation_0-logloss:0.44927
# [182]	validation_0-logloss:0.44888
# [183]	validation_0-logloss:0.44860
# [184]	validation_0-logloss:0.44820
# [185]	validation_0-logloss:0.44756
# [186]	validation_0-logloss:0.44736
# [187]	validation_0-logloss:0.44672
# [188]	validation_0-logloss:0.44635
# [189]	validation_0-logloss:0.44614
# [190]	validation_0-logloss:0.44577
# [191]	validation_0-logloss:0.44543
# [192]	validation_0-logloss:0.44479
# [193]	validation_0-logloss:0.44416
# [194]	validation_0-logloss:0.44392
# [195]	validation_0-logloss:0.44356
# [196]	validation_0-logloss:0.44323
# [197]	validation_0-logloss:0.44263
# [198]	validation_0-logloss:0.44236
# [199]	validation_0-logloss:0.44217
# [0]	validation_0-logloss:0.68887
# [1]	validation_0-logloss:0.68469
# [2]	validation_0-logloss:0.68061
# [3]	validation_0-logloss:0.67662
# [4]	validation_0-logloss:0.67269
# [5]	validation_0-logloss:0.66889
# [6]	validation_0-logloss:0.66516
# [7]	validation_0-logloss:0.66148
# [8]	validation_0-logloss:0.65793
# [9]	validation_0-logloss:0.65441
# [10]	validation_0-logloss:0.65099
# [11]	validation_0-logloss:0.64770
# [12]	validation_0-logloss:0.64440
# [13]	validation_0-logloss:0.64125
# [14]	validation_0-logloss:0.63814
# [15]	validation_0-logloss:0.63510
# [16]	validation_0-logloss:0.63208
# [17]	validation_0-logloss:0.62919
# [18]	validation_0-logloss:0.62633
# [19]	validation_0-logloss:0.62350
# [20]	validation_0-logloss:0.62077
# [21]	validation_0-logloss:0.61806
# [22]	validation_0-logloss:0.61539
# [23]	validation_0-logloss:0.61278
# [24]	validation_0-logloss:0.61013
# [25]	validation_0-logloss:0.60767
# [26]	validation_0-logloss:0.60520
# [27]	validation_0-logloss:0.60277
# [28]	validation_0-logloss:0.60041
# [29]	validation_0-logloss:0.59808
# [30]	validation_0-logloss:0.59579
# [31]	validation_0-logloss:0.59354
# [32]	validation_0-logloss:0.59132
# [33]	validation_0-logloss:0.58918
# [34]	validation_0-logloss:0.58706
# [35]	validation_0-logloss:0.58497
# [36]	validation_0-logloss:0.58292
# [37]	validation_0-logloss:0.58091
# [38]	validation_0-logloss:0.57893
# [39]	validation_0-logloss:0.57706
# [40]	validation_0-logloss:0.57518
# [41]	validation_0-logloss:0.57330
# [42]	validation_0-logloss:0.57146
# [43]	validation_0-logloss:0.56966
# [44]	validation_0-logloss:0.56788
# [45]	validation_0-logloss:0.56614
# [46]	validation_0-logloss:0.56444
# [47]	validation_0-logloss:0.56275
# [48]	validation_0-logloss:0.56113
# [49]	validation_0-logloss:0.55951
# [50]	validation_0-logloss:0.55797
# [51]	validation_0-logloss:0.55634
# [52]	validation_0-logloss:0.55481
# [53]	validation_0-logloss:0.55324
# [54]	validation_0-logloss:0.55174
# [55]	validation_0-logloss:0.55021
# [56]	validation_0-logloss:0.54878
# [57]	validation_0-logloss:0.54739
# [58]	validation_0-logloss:0.54593
# [59]	validation_0-logloss:0.54457
# [60]	validation_0-logloss:0.54316
# [61]	validation_0-logloss:0.54188
# [62]	validation_0-logloss:0.54056
# [63]	validation_0-logloss:0.53922
# [64]	validation_0-logloss:0.53797
# [65]	validation_0-logloss:0.53667
# [66]	validation_0-logloss:0.53546
# [67]	validation_0-logloss:0.53425
# [68]	validation_0-logloss:0.53300
# [69]	validation_0-logloss:0.53192
# [70]	validation_0-logloss:0.53081
# [71]	validation_0-logloss:0.52962
# [72]	validation_0-logloss:0.52851
# [73]	validation_0-logloss:0.52735
# [74]	validation_0-logloss:0.52620
# [75]	validation_0-logloss:0.52510
# [76]	validation_0-logloss:0.52368
# [77]	validation_0-logloss:0.52274
# [78]	validation_0-logloss:0.52136
# [79]	validation_0-logloss:0.52033
# [80]	validation_0-logloss:0.51899
# [81]	validation_0-logloss:0.51804
# [82]	validation_0-logloss:0.51707
# [83]	validation_0-logloss:0.51577
# [84]	validation_0-logloss:0.51450
# [85]	validation_0-logloss:0.51358
# [86]	validation_0-logloss:0.51233
# [87]	validation_0-logloss:0.51148
# [88]	validation_0-logloss:0.51059
# [89]	validation_0-logloss:0.50938
# [90]	validation_0-logloss:0.50857
# [91]	validation_0-logloss:0.50775
# [92]	validation_0-logloss:0.50687
# [93]	validation_0-logloss:0.50609
# [94]	validation_0-logloss:0.50524
# [95]	validation_0-logloss:0.50411
# [96]	validation_0-logloss:0.50330
# [97]	validation_0-logloss:0.50219
# [98]	validation_0-logloss:0.50149
# [99]	validation_0-logloss:0.50070
# [100]	validation_0-logloss:0.49963
# [101]	validation_0-logloss:0.49896
# [102]	validation_0-logloss:0.49791
# [103]	validation_0-logloss:0.49717
# [104]	validation_0-logloss:0.49614
# [105]	validation_0-logloss:0.49540
# [106]	validation_0-logloss:0.49440
# [107]	validation_0-logloss:0.49376
# [108]	validation_0-logloss:0.49305
# [109]	validation_0-logloss:0.49208
# [110]	validation_0-logloss:0.49108
# [111]	validation_0-logloss:0.49011
# [112]	validation_0-logloss:0.48942
# [113]	validation_0-logloss:0.48849
# [114]	validation_0-logloss:0.48784
# [115]	validation_0-logloss:0.48690
# [116]	validation_0-logloss:0.48636
# [117]	validation_0-logloss:0.48584
# [118]	validation_0-logloss:0.48521
# [119]	validation_0-logloss:0.48462
# [120]	validation_0-logloss:0.48406
# [121]	validation_0-logloss:0.48352
# [122]	validation_0-logloss:0.48293
# [123]	validation_0-logloss:0.48240
# [124]	validation_0-logloss:0.48188
# [125]	validation_0-logloss:0.48136
# [126]	validation_0-logloss:0.48078
# [127]	validation_0-logloss:0.48024
# [128]	validation_0-logloss:0.47964
# [129]	validation_0-logloss:0.47870
# [130]	validation_0-logloss:0.47810
# [131]	validation_0-logloss:0.47759
# [132]	validation_0-logloss:0.47669
# [133]	validation_0-logloss:0.47618
# [134]	validation_0-logloss:0.47560
# [135]	validation_0-logloss:0.47475
# [136]	validation_0-logloss:0.47420
# [137]	validation_0-logloss:0.47345
# [138]	validation_0-logloss:0.47289
# [139]	validation_0-logloss:0.47235
# [140]	validation_0-logloss:0.47153
# [141]	validation_0-logloss:0.47112
# [142]	validation_0-logloss:0.47026
# [143]	validation_0-logloss:0.46986
# [144]	validation_0-logloss:0.46933
# [145]	validation_0-logloss:0.46850
# [146]	validation_0-logloss:0.46812
# [147]	validation_0-logloss:0.46729
# [148]	validation_0-logloss:0.46678
# [149]	validation_0-logloss:0.46633
# [150]	validation_0-logloss:0.46585
# [151]	validation_0-logloss:0.46535
# [152]	validation_0-logloss:0.46497
# [153]	validation_0-logloss:0.46418
# [154]	validation_0-logloss:0.46340
# [155]	validation_0-logloss:0.46301
# [156]	validation_0-logloss:0.46253
# [157]	validation_0-logloss:0.46206
# [158]	validation_0-logloss:0.46154
# [159]	validation_0-logloss:0.46105
# [160]	validation_0-logloss:0.46075
# [161]	validation_0-logloss:0.45996
# [162]	validation_0-logloss:0.45951
# [163]	validation_0-logloss:0.45910
# [164]	validation_0-logloss:0.45833
# [165]	validation_0-logloss:0.45790
# [166]	validation_0-logloss:0.45753
# [167]	validation_0-logloss:0.45681
# [168]	validation_0-logloss:0.45638
# [169]	validation_0-logloss:0.45593
# [170]	validation_0-logloss:0.45551
# [171]	validation_0-logloss:0.45510
# [172]	validation_0-logloss:0.45476
# [173]	validation_0-logloss:0.45402
# [174]	validation_0-logloss:0.45361
# [175]	validation_0-logloss:0.45328
# [176]	validation_0-logloss:0.45288
# [177]	validation_0-logloss:0.45245
# [178]	validation_0-logloss:0.45202
# [179]	validation_0-logloss:0.45134
# [180]	validation_0-logloss:0.45105
# [181]	validation_0-logloss:0.45063
# [182]	validation_0-logloss:0.45033
# [183]	validation_0-logloss:0.44966
# [184]	validation_0-logloss:0.44942
# [185]	validation_0-logloss:0.44900
# [186]	validation_0-logloss:0.44860
# [187]	validation_0-logloss:0.44823
# [188]	validation_0-logloss:0.44802
# [189]	validation_0-logloss:0.44738
# [190]	validation_0-logloss:0.44709
# [191]	validation_0-logloss:0.44669
# [192]	validation_0-logloss:0.44647
# [193]	validation_0-logloss:0.44619
# [194]	validation_0-logloss:0.44554
# [195]	validation_0-logloss:0.44517
# [196]	validation_0-logloss:0.44479
# [197]	validation_0-logloss:0.44441
# [198]	validation_0-logloss:0.44413
# [199]	validation_0-logloss:0.44348
# [0]	validation_0-logloss:0.68884
# [1]	validation_0-logloss:0.68463
# [2]	validation_0-logloss:0.68050
# [3]	validation_0-logloss:0.67648
# [4]	validation_0-logloss:0.67253
# [5]	validation_0-logloss:0.66866
# [6]	validation_0-logloss:0.66486
# [7]	validation_0-logloss:0.66123
# [8]	validation_0-logloss:0.65760
# [9]	validation_0-logloss:0.65409
# [10]	validation_0-logloss:0.65062
# [11]	validation_0-logloss:0.64723
# [12]	validation_0-logloss:0.64391
# [13]	validation_0-logloss:0.64072
# [14]	validation_0-logloss:0.63754
# [15]	validation_0-logloss:0.63442
# [16]	validation_0-logloss:0.63140
# [17]	validation_0-logloss:0.62840
# [18]	validation_0-logloss:0.62548
# [19]	validation_0-logloss:0.62264
# [20]	validation_0-logloss:0.61982
# [21]	validation_0-logloss:0.61714
# [22]	validation_0-logloss:0.61446
# [23]	validation_0-logloss:0.61183
# [24]	validation_0-logloss:0.60927
# [25]	validation_0-logloss:0.60663
# [26]	validation_0-logloss:0.60414
# [27]	validation_0-logloss:0.60170
# [28]	validation_0-logloss:0.59932
# [29]	validation_0-logloss:0.59702
# [30]	validation_0-logloss:0.59474
# [31]	validation_0-logloss:0.59235
# [32]	validation_0-logloss:0.59015
# [33]	validation_0-logloss:0.58797
# [34]	validation_0-logloss:0.58584
# [35]	validation_0-logloss:0.58376
# [36]	validation_0-logloss:0.58176
# [37]	validation_0-logloss:0.57974
# [38]	validation_0-logloss:0.57774
# [39]	validation_0-logloss:0.57581
# [40]	validation_0-logloss:0.57396
# [41]	validation_0-logloss:0.57209
# [42]	validation_0-logloss:0.57028
# [43]	validation_0-logloss:0.56834
# [44]	validation_0-logloss:0.56647
# [45]	validation_0-logloss:0.56475
# [46]	validation_0-logloss:0.56302
# [47]	validation_0-logloss:0.56139
# [48]	validation_0-logloss:0.55964
# [49]	validation_0-logloss:0.55788
# [50]	validation_0-logloss:0.55630
# [51]	validation_0-logloss:0.55472
# [52]	validation_0-logloss:0.55309
# [53]	validation_0-logloss:0.55158
# [54]	validation_0-logloss:0.55011
# [55]	validation_0-logloss:0.54867
# [56]	validation_0-logloss:0.54726
# [57]	validation_0-logloss:0.54587
# [58]	validation_0-logloss:0.54452
# [59]	validation_0-logloss:0.54312
# [60]	validation_0-logloss:0.54180
# [61]	validation_0-logloss:0.54053
# [62]	validation_0-logloss:0.53922
# [63]	validation_0-logloss:0.53797
# [64]	validation_0-logloss:0.53675
# [65]	validation_0-logloss:0.53554
# [66]	validation_0-logloss:0.53437
# [67]	validation_0-logloss:0.53320
# [68]	validation_0-logloss:0.53155
# [69]	validation_0-logloss:0.53036
# [70]	validation_0-logloss:0.52926
# [71]	validation_0-logloss:0.52818
# [72]	validation_0-logloss:0.52712
# [73]	validation_0-logloss:0.52555
# [74]	validation_0-logloss:0.52447
# [75]	validation_0-logloss:0.52291
# [76]	validation_0-logloss:0.52191
# [77]	validation_0-logloss:0.52044
# [78]	validation_0-logloss:0.51894
# [79]	validation_0-logloss:0.51796
# [80]	validation_0-logloss:0.51686
# [81]	validation_0-logloss:0.51571
# [82]	validation_0-logloss:0.51469
# [83]	validation_0-logloss:0.51353
# [84]	validation_0-logloss:0.51211
# [85]	validation_0-logloss:0.51075
# [86]	validation_0-logloss:0.50964
# [87]	validation_0-logloss:0.50869
# [88]	validation_0-logloss:0.50762
# [89]	validation_0-logloss:0.50676
# [90]	validation_0-logloss:0.50545
# [91]	validation_0-logloss:0.50441
# [92]	validation_0-logloss:0.50351
# [93]	validation_0-logloss:0.50251
# [94]	validation_0-logloss:0.50122
# [95]	validation_0-logloss:0.49996
# [96]	validation_0-logloss:0.49900
# [97]	validation_0-logloss:0.49814
# [98]	validation_0-logloss:0.49721
# [99]	validation_0-logloss:0.49599
# [100]	validation_0-logloss:0.49508
# [101]	validation_0-logloss:0.49389
# [102]	validation_0-logloss:0.49267
# [103]	validation_0-logloss:0.49197
# [104]	validation_0-logloss:0.49118
# [105]	validation_0-logloss:0.49032
# [106]	validation_0-logloss:0.48946
# [107]	validation_0-logloss:0.48836
# [108]	validation_0-logloss:0.48769
# [109]	validation_0-logloss:0.48698
# [110]	validation_0-logloss:0.48617
# [111]	validation_0-logloss:0.48535
# [112]	validation_0-logloss:0.48429
# [113]	validation_0-logloss:0.48324
# [114]	validation_0-logloss:0.48213
# [115]	validation_0-logloss:0.48157
# [116]	validation_0-logloss:0.48103
# [117]	validation_0-logloss:0.48050
# [118]	validation_0-logloss:0.47998
# [119]	validation_0-logloss:0.47932
# [120]	validation_0-logloss:0.47858
# [121]	validation_0-logloss:0.47805
# [122]	validation_0-logloss:0.47707
# [123]	validation_0-logloss:0.47635
# [124]	validation_0-logloss:0.47573
# [125]	validation_0-logloss:0.47469
# [126]	validation_0-logloss:0.47373
# [127]	validation_0-logloss:0.47328
# [128]	validation_0-logloss:0.47259
# [129]	validation_0-logloss:0.47166
# [130]	validation_0-logloss:0.47107
# [131]	validation_0-logloss:0.47041
# [132]	validation_0-logloss:0.46949
# [133]	validation_0-logloss:0.46907
# [134]	validation_0-logloss:0.46843
# [135]	validation_0-logloss:0.46787
# [136]	validation_0-logloss:0.46690
# [137]	validation_0-logloss:0.46600
# [138]	validation_0-logloss:0.46512
# [139]	validation_0-logloss:0.46417
# [140]	validation_0-logloss:0.46364
# [141]	validation_0-logloss:0.46273
# [142]	validation_0-logloss:0.46181
# [143]	validation_0-logloss:0.46123
# [144]	validation_0-logloss:0.46064
# [145]	validation_0-logloss:0.45980
# [146]	validation_0-logloss:0.45944
# [147]	validation_0-logloss:0.45858
# [148]	validation_0-logloss:0.45803
# [149]	validation_0-logloss:0.45715
# [150]	validation_0-logloss:0.45667
# [151]	validation_0-logloss:0.45581
# [152]	validation_0-logloss:0.45500
# [153]	validation_0-logloss:0.45467
# [154]	validation_0-logloss:0.45413
# [155]	validation_0-logloss:0.45366
# [156]	validation_0-logloss:0.45283
# [157]	validation_0-logloss:0.45204
# [158]	validation_0-logloss:0.45121
# [159]	validation_0-logloss:0.45070
# [160]	validation_0-logloss:0.44988
# [161]	validation_0-logloss:0.44911
# [162]	validation_0-logloss:0.44867
# [163]	validation_0-logloss:0.44825
# [164]	validation_0-logloss:0.44796
# [165]	validation_0-logloss:0.44716
# [166]	validation_0-logloss:0.44667
# [167]	validation_0-logloss:0.44590
# [168]	validation_0-logloss:0.44516
# [169]	validation_0-logloss:0.44474
# [170]	validation_0-logloss:0.44408
# [171]	validation_0-logloss:0.44361
# [172]	validation_0-logloss:0.44323
# [173]	validation_0-logloss:0.44298
# [174]	validation_0-logloss:0.44258
# [175]	validation_0-logloss:0.44194
# [176]	validation_0-logloss:0.44148
# [177]	validation_0-logloss:0.44078
# [178]	validation_0-logloss:0.44006
# [179]	validation_0-logloss:0.43968
# [180]	validation_0-logloss:0.43945
# [181]	validation_0-logloss:0.43883
# [182]	validation_0-logloss:0.43839
# [183]	validation_0-logloss:0.43771
# [184]	validation_0-logloss:0.43702
# [185]	validation_0-logloss:0.43665
# [186]	validation_0-logloss:0.43633
# [187]	validation_0-logloss:0.43590
# [188]	validation_0-logloss:0.43524
# [189]	validation_0-logloss:0.43499
# [190]	validation_0-logloss:0.43467
# [191]	validation_0-logloss:0.43426
# [192]	validation_0-logloss:0.43391
# [193]	validation_0-logloss:0.43363
# [194]	validation_0-logloss:0.43323
# [195]	validation_0-logloss:0.43266
# [196]	validation_0-logloss:0.43227
# [197]	validation_0-logloss:0.43199
# [198]	validation_0-logloss:0.43132
# [199]	validation_0-logloss:0.43107
# [200]	validation_0-logloss:0.43067
# [201]	validation_0-logloss:0.43001
# [202]	validation_0-logloss:0.42966
# [203]	validation_0-logloss:0.42936
# [204]	validation_0-logloss:0.42871
# [205]	validation_0-logloss:0.42830
# [206]	validation_0-logloss:0.42765
# [207]	validation_0-logloss:0.42742
# [208]	validation_0-logloss:0.42724
# [209]	validation_0-logloss:0.42670
# [210]	validation_0-logloss:0.42634
# [211]	validation_0-logloss:0.42570
# [212]	validation_0-logloss:0.42530
# [213]	validation_0-logloss:0.42465
# [214]	validation_0-logloss:0.42448
# [215]	validation_0-logloss:0.42413
# [216]	validation_0-logloss:0.42384
# [217]	validation_0-logloss:0.42323
# [218]	validation_0-logloss:0.42284
# [219]	validation_0-logloss:0.42260
# [220]	validation_0-logloss:0.42201
# [221]	validation_0-logloss:0.42163
# [222]	validation_0-logloss:0.42140
# [223]	validation_0-logloss:0.42109
# [224]	validation_0-logloss:0.42078
# [225]	validation_0-logloss:0.42061
# [226]	validation_0-logloss:0.42024
# [227]	validation_0-logloss:0.41995
# [228]	validation_0-logloss:0.41961
# [229]	validation_0-logloss:0.41922
# [230]	validation_0-logloss:0.41897
# [231]	validation_0-logloss:0.41838
# [232]	validation_0-logloss:0.41780
# [233]	validation_0-logloss:0.41766
# [234]	validation_0-logloss:0.41722
# [235]	validation_0-logloss:0.41685
# [236]	validation_0-logloss:0.41656
# [237]	validation_0-logloss:0.41612
# [238]	validation_0-logloss:0.41576
# [239]	validation_0-logloss:0.41551
# [240]	validation_0-logloss:0.41497
# [241]	validation_0-logloss:0.41472
# [242]	validation_0-logloss:0.41449
# [243]	validation_0-logloss:0.41421
# [244]	validation_0-logloss:0.41370
# [245]	validation_0-logloss:0.41329
# [246]	validation_0-logloss:0.41293
# [247]	validation_0-logloss:0.41271
# [248]	validation_0-logloss:0.41241
# [249]	validation_0-logloss:0.41191
# [250]	validation_0-logloss:0.41167
# [251]	validation_0-logloss:0.41110
# [252]	validation_0-logloss:0.41071
# [253]	validation_0-logloss:0.41038
# [254]	validation_0-logloss:0.40990
# [255]	validation_0-logloss:0.40967
# [256]	validation_0-logloss:0.40948
# [257]	validation_0-logloss:0.40902
# [258]	validation_0-logloss:0.40856
# [259]	validation_0-logloss:0.40801
# [260]	validation_0-logloss:0.40779
# [261]	validation_0-logloss:0.40749
# [262]	validation_0-logloss:0.40695
# [263]	validation_0-logloss:0.40647
# [264]	validation_0-logloss:0.40617
# [265]	validation_0-logloss:0.40548
# [266]	validation_0-logloss:0.40496
# [267]	validation_0-logloss:0.40444
# [268]	validation_0-logloss:0.40396
# [269]	validation_0-logloss:0.40329
# [270]	validation_0-logloss:0.40308
# [271]	validation_0-logloss:0.40264
# [272]	validation_0-logloss:0.40214
# [273]	validation_0-logloss:0.40146
# [274]	validation_0-logloss:0.40081
# [275]	validation_0-logloss:0.40061
# [276]	validation_0-logloss:0.40018
# [277]	validation_0-logloss:0.39953
# [278]	validation_0-logloss:0.39923
# [279]	validation_0-logloss:0.39873
# [280]	validation_0-logloss:0.39827
# [281]	validation_0-logloss:0.39763
# [282]	validation_0-logloss:0.39740
# [283]	validation_0-logloss:0.39698
# [284]	validation_0-logloss:0.39649
# [285]	validation_0-logloss:0.39586
# [286]	validation_0-logloss:0.39541
# [287]	validation_0-logloss:0.39514
# [288]	validation_0-logloss:0.39453
# [289]	validation_0-logloss:0.39415
# [290]	validation_0-logloss:0.39367
# [291]	validation_0-logloss:0.39306
# [292]	validation_0-logloss:0.39273
# [293]	validation_0-logloss:0.39243
# [294]	validation_0-logloss:0.39203
# [295]	validation_0-logloss:0.39153
# [296]	validation_0-logloss:0.39107
# [297]	validation_0-logloss:0.39093
# [298]	validation_0-logloss:0.39063
# [299]	validation_0-logloss:0.39018
# [0]	validation_0-logloss:0.68886
# [1]	validation_0-logloss:0.68468
# [2]	validation_0-logloss:0.68059
# [3]	validation_0-logloss:0.67662
# [4]	validation_0-logloss:0.67271
# [5]	validation_0-logloss:0.66890
# [6]	validation_0-logloss:0.66517
# [7]	validation_0-logloss:0.66151
# [8]	validation_0-logloss:0.65799
# [9]	validation_0-logloss:0.65450
# [10]	validation_0-logloss:0.65113
# [11]	validation_0-logloss:0.64779
# [12]	validation_0-logloss:0.64426
# [13]	validation_0-logloss:0.64109
# [14]	validation_0-logloss:0.63790
# [15]	validation_0-logloss:0.63457
# [16]	validation_0-logloss:0.63155
# [17]	validation_0-logloss:0.62855
# [18]	validation_0-logloss:0.62540
# [19]	validation_0-logloss:0.62262
# [20]	validation_0-logloss:0.61988
# [21]	validation_0-logloss:0.61718
# [22]	validation_0-logloss:0.61446
# [23]	validation_0-logloss:0.61178
# [24]	validation_0-logloss:0.60925
# [25]	validation_0-logloss:0.60680
# [26]	validation_0-logloss:0.60437
# [27]	validation_0-logloss:0.60189
# [28]	validation_0-logloss:0.59961
# [29]	validation_0-logloss:0.59722
# [30]	validation_0-logloss:0.59498
# [31]	validation_0-logloss:0.59271
# [32]	validation_0-logloss:0.59052
# [33]	validation_0-logloss:0.58836
# [34]	validation_0-logloss:0.58615
# [35]	validation_0-logloss:0.58404
# [36]	validation_0-logloss:0.58204
# [37]	validation_0-logloss:0.57999
# [38]	validation_0-logloss:0.57811
# [39]	validation_0-logloss:0.57604
# [40]	validation_0-logloss:0.57416
# [41]	validation_0-logloss:0.57230
# [42]	validation_0-logloss:0.57050
# [43]	validation_0-logloss:0.56868
# [44]	validation_0-logloss:0.56677
# [45]	validation_0-logloss:0.56501
# [46]	validation_0-logloss:0.56335
# [47]	validation_0-logloss:0.56167
# [48]	validation_0-logloss:0.55999
# [49]	validation_0-logloss:0.55823
# [50]	validation_0-logloss:0.55667
# [51]	validation_0-logloss:0.55503
# [52]	validation_0-logloss:0.55348
# [53]	validation_0-logloss:0.55195
# [54]	validation_0-logloss:0.55002
# [55]	validation_0-logloss:0.54858
# [56]	validation_0-logloss:0.54717
# [57]	validation_0-logloss:0.54579
# [58]	validation_0-logloss:0.54443
# [59]	validation_0-logloss:0.54310
# [60]	validation_0-logloss:0.54179
# [61]	validation_0-logloss:0.54053
# [62]	validation_0-logloss:0.53930
# [63]	validation_0-logloss:0.53806
# [64]	validation_0-logloss:0.53686
# [65]	validation_0-logloss:0.53564
# [66]	validation_0-logloss:0.53447
# [67]	validation_0-logloss:0.53327
# [68]	validation_0-logloss:0.53209
# [69]	validation_0-logloss:0.53102
# [70]	validation_0-logloss:0.52989
# [71]	validation_0-logloss:0.52884
# [72]	validation_0-logloss:0.52774
# [73]	validation_0-logloss:0.52670
# [74]	validation_0-logloss:0.52565
# [75]	validation_0-logloss:0.52458
# [76]	validation_0-logloss:0.52360
# [77]	validation_0-logloss:0.52256
# [78]	validation_0-logloss:0.52153
# [79]	validation_0-logloss:0.52012
# [80]	validation_0-logloss:0.51924
# [81]	validation_0-logloss:0.51787
# [82]	validation_0-logloss:0.51690
# [83]	validation_0-logloss:0.51556
# [84]	validation_0-logloss:0.51471
# [85]	validation_0-logloss:0.51340
# [86]	validation_0-logloss:0.51248
# [87]	validation_0-logloss:0.51120
# [88]	validation_0-logloss:0.50994
# [89]	validation_0-logloss:0.50907
# [90]	validation_0-logloss:0.50824
# [91]	validation_0-logloss:0.50702
# [92]	validation_0-logloss:0.50579
# [93]	validation_0-logloss:0.50494
# [94]	validation_0-logloss:0.50420
# [95]	validation_0-logloss:0.50303
# [96]	validation_0-logloss:0.50218
# [97]	validation_0-logloss:0.50103
# [98]	validation_0-logloss:0.50026
# [99]	validation_0-logloss:0.49912
# [100]	validation_0-logloss:0.49831
# [101]	validation_0-logloss:0.49753
# [102]	validation_0-logloss:0.49643
# [103]	validation_0-logloss:0.49528
# [104]	validation_0-logloss:0.49467
# [105]	validation_0-logloss:0.49361
# [106]	validation_0-logloss:0.49249
# [107]	validation_0-logloss:0.49185
# [108]	validation_0-logloss:0.49126
# [109]	validation_0-logloss:0.49026
# [110]	validation_0-logloss:0.48956
# [111]	validation_0-logloss:0.48858
# [112]	validation_0-logloss:0.48790
# [113]	validation_0-logloss:0.48729
# [114]	validation_0-logloss:0.48664
# [115]	validation_0-logloss:0.48607
# [116]	validation_0-logloss:0.48512
# [117]	validation_0-logloss:0.48449
# [118]	validation_0-logloss:0.48394
# [119]	validation_0-logloss:0.48303
# [120]	validation_0-logloss:0.48239
# [121]	validation_0-logloss:0.48187
# [122]	validation_0-logloss:0.48127
# [123]	validation_0-logloss:0.48057
# [124]	validation_0-logloss:0.47967
# [125]	validation_0-logloss:0.47899
# [126]	validation_0-logloss:0.47846
# [127]	validation_0-logloss:0.47787
# [128]	validation_0-logloss:0.47722
# [129]	validation_0-logloss:0.47668
# [130]	validation_0-logloss:0.47580
# [131]	validation_0-logloss:0.47522
# [132]	validation_0-logloss:0.47460
# [133]	validation_0-logloss:0.47374
# [134]	validation_0-logloss:0.47313
# [135]	validation_0-logloss:0.47259
# [136]	validation_0-logloss:0.47174
# [137]	validation_0-logloss:0.47131
# [138]	validation_0-logloss:0.47087
# [139]	validation_0-logloss:0.47005
# [140]	validation_0-logloss:0.46964
# [141]	validation_0-logloss:0.46913
# [142]	validation_0-logloss:0.46832
# [143]	validation_0-logloss:0.46786
# [144]	validation_0-logloss:0.46736
# [145]	validation_0-logloss:0.46693
# [146]	validation_0-logloss:0.46616
# [147]	validation_0-logloss:0.46567
# [148]	validation_0-logloss:0.46529
# [149]	validation_0-logloss:0.46480
# [150]	validation_0-logloss:0.46429
# [151]	validation_0-logloss:0.46354
# [152]	validation_0-logloss:0.46315
# [153]	validation_0-logloss:0.46265
# [154]	validation_0-logloss:0.46188
# [155]	validation_0-logloss:0.46139
# [156]	validation_0-logloss:0.46092
# [157]	validation_0-logloss:0.46059
# [158]	validation_0-logloss:0.46010
# [159]	validation_0-logloss:0.45935
# [160]	validation_0-logloss:0.45902
# [161]	validation_0-logloss:0.45855
# [162]	validation_0-logloss:0.45781
# [163]	validation_0-logloss:0.45748
# [164]	validation_0-logloss:0.45704
# [165]	validation_0-logloss:0.45659
# [166]	validation_0-logloss:0.45586
# [167]	validation_0-logloss:0.45541
# [168]	validation_0-logloss:0.45514
# [169]	validation_0-logloss:0.45444
# [170]	validation_0-logloss:0.45402
# [171]	validation_0-logloss:0.45370
# [172]	validation_0-logloss:0.45326
# [173]	validation_0-logloss:0.45298
# [174]	validation_0-logloss:0.45230
# [175]	validation_0-logloss:0.45187
# [176]	validation_0-logloss:0.45162
# [177]	validation_0-logloss:0.45122
# [178]	validation_0-logloss:0.45099
# [179]	validation_0-logloss:0.45030
# [180]	validation_0-logloss:0.44964
# [181]	validation_0-logloss:0.44927
# [182]	validation_0-logloss:0.44888
# [183]	validation_0-logloss:0.44860
# [184]	validation_0-logloss:0.44820
# [185]	validation_0-logloss:0.44756
# [186]	validation_0-logloss:0.44736
# [187]	validation_0-logloss:0.44672
# [188]	validation_0-logloss:0.44635
# [189]	validation_0-logloss:0.44614
# [190]	validation_0-logloss:0.44577
# [191]	validation_0-logloss:0.44543
# [192]	validation_0-logloss:0.44479
# [193]	validation_0-logloss:0.44416
# [194]	validation_0-logloss:0.44392
# [195]	validation_0-logloss:0.44356
# ...
# [375]	validation_0-logloss:0.21699
# [376]	validation_0-logloss:0.21705
# [377]	validation_0-logloss:0.21690
# [378]	validation_0-logloss:0.21699
# [379]	validation_0-logloss:0.21696
# [380]	validation_0-logloss:0.21673
# [381]	validation_0-logloss:0.21672
# [382]	validation_0-logloss:0.21660
# [383]	validation_0-logloss:0.21611
# [384]	validation_0-logloss:0.21590
# [385]	validation_0-logloss:0.21601
# [386]	validation_0-logloss:0.21608
# [387]	validation_0-logloss:0.21577
# [388]	validation_0-logloss:0.21589
# [389]	validation_0-logloss:0.21600
# [390]	validation_0-logloss:0.21610
# [391]	validation_0-logloss:0.21603
# [392]	validation_0-logloss:0.21595
# [393]	validation_0-logloss:0.21561
# [394]	validation_0-logloss:0.21548
# [395]	validation_0-logloss:0.21529
# [396]	validation_0-logloss:0.21538
# [397]	validation_0-logloss:0.21545
# [398]	validation_0-logloss:0.21540
# [399]	validation_0-logloss:0.21529
# [0]	validation_0-logloss:0.68884
# [1]	validation_0-logloss:0.68464
# [2]	validation_0-logloss:0.68054
# [3]	validation_0-logloss:0.67653
# [4]	validation_0-logloss:0.67261
# [5]	validation_0-logloss:0.66878
# [6]	validation_0-logloss:0.66504
# [7]	validation_0-logloss:0.66138
# [8]	validation_0-logloss:0.65780
# [9]	validation_0-logloss:0.65430
# [10]	validation_0-logloss:0.65088
# [11]	validation_0-logloss:0.64753
# [12]	validation_0-logloss:0.64426
# [13]	validation_0-logloss:0.64107
# [14]	validation_0-logloss:0.63795
# [15]	validation_0-logloss:0.63489
# [16]	validation_0-logloss:0.63188
# [17]	validation_0-logloss:0.62894
# [18]	validation_0-logloss:0.62605
# [19]	validation_0-logloss:0.62325
# [20]	validation_0-logloss:0.62046
# [21]	validation_0-logloss:0.61778
# [22]	validation_0-logloss:0.61511
# [23]	validation_0-logloss:0.61252
# [24]	validation_0-logloss:0.60996
# [25]	validation_0-logloss:0.60749
# [26]	validation_0-logloss:0.60505
# [27]	validation_0-logloss:0.60262
# [28]	validation_0-logloss:0.60023
# [29]	validation_0-logloss:0.59792
# [30]	validation_0-logloss:0.59568
# [31]	validation_0-logloss:0.59345
# [32]	validation_0-logloss:0.59128
# [33]	validation_0-logloss:0.58914
# [34]	validation_0-logloss:0.58708
# [35]	validation_0-logloss:0.58503
# [36]	validation_0-logloss:0.58299
# [37]	validation_0-logloss:0.58100
# [38]	validation_0-logloss:0.57910
# [39]	validation_0-logloss:0.57718
# [40]	validation_0-logloss:0.57527
# [41]	validation_0-logloss:0.57341
# [42]	validation_0-logloss:0.57162
# [43]	validation_0-logloss:0.56983
# [44]	validation_0-logloss:0.56808
# [45]	validation_0-logloss:0.56628
# [46]	validation_0-logloss:0.56456
# [47]	validation_0-logloss:0.56283
# [48]	validation_0-logloss:0.56116
# [49]	validation_0-logloss:0.55956
# [50]	validation_0-logloss:0.55790
# [51]	validation_0-logloss:0.55633
# [52]	validation_0-logloss:0.55472
# [53]	validation_0-logloss:0.55326
# [54]	validation_0-logloss:0.55171
# [55]	validation_0-logloss:0.55005
# [56]	validation_0-logloss:0.54860
# [57]	validation_0-logloss:0.54699
# [58]	validation_0-logloss:0.54559
# [59]	validation_0-logloss:0.54416
# [60]	validation_0-logloss:0.54274
# [61]	validation_0-logloss:0.54101
# [62]	validation_0-logloss:0.53970
# [63]	validation_0-logloss:0.53844
# [64]	validation_0-logloss:0.53699
# [65]	validation_0-logloss:0.53577
# [66]	validation_0-logloss:0.53457
# [67]	validation_0-logloss:0.53341
# [68]	validation_0-logloss:0.53226
# [69]	validation_0-logloss:0.53114
# [70]	validation_0-logloss:0.53004
# [71]	validation_0-logloss:0.52895
# [72]	validation_0-logloss:0.52788
# [73]	validation_0-logloss:0.52637
# [74]	validation_0-logloss:0.52535
# [75]	validation_0-logloss:0.52434
# [76]	validation_0-logloss:0.52332
# [77]	validation_0-logloss:0.52234
# [78]	validation_0-logloss:0.52122
# [79]	validation_0-logloss:0.51980
# [80]	validation_0-logloss:0.51843
# [81]	validation_0-logloss:0.51706
# [82]	validation_0-logloss:0.51615
# [83]	validation_0-logloss:0.51526
# [84]	validation_0-logloss:0.51440
# [85]	validation_0-logloss:0.51356
# [86]	validation_0-logloss:0.51274
# [87]	validation_0-logloss:0.51191
# [88]	validation_0-logloss:0.51066
# [89]	validation_0-logloss:0.50987
# [90]	validation_0-logloss:0.50897
# [91]	validation_0-logloss:0.50775
# [92]	validation_0-logloss:0.50698
# [93]	validation_0-logloss:0.50610
# [94]	validation_0-logloss:0.50482
# [95]	validation_0-logloss:0.50367
# [96]	validation_0-logloss:0.50242
# [97]	validation_0-logloss:0.50159
# [98]	validation_0-logloss:0.50078
# [99]	validation_0-logloss:0.49985
# [100]	validation_0-logloss:0.49921
# [101]	validation_0-logloss:0.49796
# [102]	validation_0-logloss:0.49719
# [103]	validation_0-logloss:0.49632
# [104]	validation_0-logloss:0.49522
# [105]	validation_0-logloss:0.49436
# [106]	validation_0-logloss:0.49363
# [107]	validation_0-logloss:0.49281
# [108]	validation_0-logloss:0.49174
# [109]	validation_0-logloss:0.49063
# [110]	validation_0-logloss:0.49007
# [111]	validation_0-logloss:0.48927
# [112]	validation_0-logloss:0.48859
# [113]	validation_0-logloss:0.48781
# [114]	validation_0-logloss:0.48680
# [115]	validation_0-logloss:0.48579
# [116]	validation_0-logloss:0.48523
# [117]	validation_0-logloss:0.48468
# [118]	validation_0-logloss:0.48414
# [119]	validation_0-logloss:0.48349
# [120]	validation_0-logloss:0.48275
# [121]	validation_0-logloss:0.48225
# [122]	validation_0-logloss:0.48154
# [123]	validation_0-logloss:0.48092
# [124]	validation_0-logloss:0.48004
# [125]	validation_0-logloss:0.47910
# [126]	validation_0-logloss:0.47848
# [127]	validation_0-logloss:0.47780
# [128]	validation_0-logloss:0.47690
# [129]	validation_0-logloss:0.47625
# [130]	validation_0-logloss:0.47567
# [131]	validation_0-logloss:0.47471
# [132]	validation_0-logloss:0.47382
# [133]	validation_0-logloss:0.47326
# [134]	validation_0-logloss:0.47228
# [135]	validation_0-logloss:0.47171
# [136]	validation_0-logloss:0.47079
# [137]	validation_0-logloss:0.46995
# [138]	validation_0-logloss:0.46906
# [139]	validation_0-logloss:0.46853
# [140]	validation_0-logloss:0.46805
# [141]	validation_0-logloss:0.46722
# [142]	validation_0-logloss:0.46669
# [143]	validation_0-logloss:0.46625
# [144]	validation_0-logloss:0.46542
# [145]	validation_0-logloss:0.46500
# [146]	validation_0-logloss:0.46419
# [147]	validation_0-logloss:0.46368
# [148]	validation_0-logloss:0.46327
# [149]	validation_0-logloss:0.46275
# [150]	validation_0-logloss:0.46237
# [151]	validation_0-logloss:0.46158
# [152]	validation_0-logloss:0.46108
# [153]	validation_0-logloss:0.46065
# [154]	validation_0-logloss:0.46016
# [155]	validation_0-logloss:0.45980
# [156]	validation_0-logloss:0.45902
# [157]	validation_0-logloss:0.45825
# [158]	validation_0-logloss:0.45778
# [159]	validation_0-logloss:0.45702
# [160]	validation_0-logloss:0.45654
# [161]	validation_0-logloss:0.45579
# [162]	validation_0-logloss:0.45504
# [163]	validation_0-logloss:0.45465
# [164]	validation_0-logloss:0.45393
# [165]	validation_0-logloss:0.45349
# [166]	validation_0-logloss:0.45272
# [167]	validation_0-logloss:0.45229
# [168]	validation_0-logloss:0.45194
# [169]	validation_0-logloss:0.45122
# [170]	validation_0-logloss:0.45078
# [171]	validation_0-logloss:0.45047
# [172]	validation_0-logloss:0.44977
# [173]	validation_0-logloss:0.44943
# [174]	validation_0-logloss:0.44902
# [175]	validation_0-logloss:0.44828
# [176]	validation_0-logloss:0.44786
# [177]	validation_0-logloss:0.44759
# [178]	validation_0-logloss:0.44690
# [179]	validation_0-logloss:0.44663
# [180]	validation_0-logloss:0.44597
# [181]	validation_0-logloss:0.44555
# [182]	validation_0-logloss:0.44485
# [183]	validation_0-logloss:0.44442
# [184]	validation_0-logloss:0.44372
# [185]	validation_0-logloss:0.44340
# [186]	validation_0-logloss:0.44300
# [187]	validation_0-logloss:0.44272
# [188]	validation_0-logloss:0.44206
# [189]	validation_0-logloss:0.44167
# [190]	validation_0-logloss:0.44144
# [191]	validation_0-logloss:0.44077
# [192]	validation_0-logloss:0.44036
# [193]	validation_0-logloss:0.44014
# [194]	validation_0-logloss:0.43976
# [195]	validation_0-logloss:0.43954
# [196]	validation_0-logloss:0.43890
# [197]	validation_0-logloss:0.43850
# [198]	validation_0-logloss:0.43822
# [199]	validation_0-logloss:0.43757
# [200]	validation_0-logloss:0.43728
# [201]	validation_0-logloss:0.43691
# [202]	validation_0-logloss:0.43670
# [203]	validation_0-logloss:0.43633
# [204]	validation_0-logloss:0.43579
# [205]	validation_0-logloss:0.43517
# [206]	validation_0-logloss:0.43479
# [207]	validation_0-logloss:0.43426
# [208]	validation_0-logloss:0.43391
# [209]	validation_0-logloss:0.43326
# [210]	validation_0-logloss:0.43289
# [211]	validation_0-logloss:0.43217
# [212]	validation_0-logloss:0.43158
# [213]	validation_0-logloss:0.43131
# [214]	validation_0-logloss:0.43097
# [215]	validation_0-logloss:0.43037
# [216]	validation_0-logloss:0.43004
# [217]	validation_0-logloss:0.42970
# [218]	validation_0-logloss:0.42912
# [219]	validation_0-logloss:0.42889
# [220]	validation_0-logloss:0.42858
# [221]	validation_0-logloss:0.42830
# [222]	validation_0-logloss:0.42800
# [223]	validation_0-logloss:0.42745
# [224]	validation_0-logloss:0.42714
# [225]	validation_0-logloss:0.42681
# [226]	validation_0-logloss:0.42649
# [227]	validation_0-logloss:0.42595
# [228]	validation_0-logloss:0.42562
# [229]	validation_0-logloss:0.42507
# [230]	validation_0-logloss:0.42477
# [231]	validation_0-logloss:0.42455
# [232]	validation_0-logloss:0.42400
# [233]	validation_0-logloss:0.42372
# [234]	validation_0-logloss:0.42343
# [235]	validation_0-logloss:0.42289
# [236]	validation_0-logloss:0.42236
# [237]	validation_0-logloss:0.42209
# [238]	validation_0-logloss:0.42185
# [239]	validation_0-logloss:0.42134
# [240]	validation_0-logloss:0.42107
# [241]	validation_0-logloss:0.42081
# [242]	validation_0-logloss:0.42030
# [243]	validation_0-logloss:0.42004
# [244]	validation_0-logloss:0.41975
# [245]	validation_0-logloss:0.41924
# [246]	validation_0-logloss:0.41899
# [247]	validation_0-logloss:0.41874
# [248]	validation_0-logloss:0.41824
# [249]	validation_0-logloss:0.41796
# [250]	validation_0-logloss:0.41749
# [251]	validation_0-logloss:0.41724
# [252]	validation_0-logloss:0.41676
# [253]	validation_0-logloss:0.41642
# [254]	validation_0-logloss:0.41615
# [255]	validation_0-logloss:0.41595
# [256]	validation_0-logloss:0.41547
# [257]	validation_0-logloss:0.41525
# [258]	validation_0-logloss:0.41499
# [259]	validation_0-logloss:0.41479
# [260]	validation_0-logloss:0.41432
# [261]	validation_0-logloss:0.41411
# [262]	validation_0-logloss:0.41351
# [263]	validation_0-logloss:0.41306
# [264]	validation_0-logloss:0.41281
# [265]	validation_0-logloss:0.41239
# [266]	validation_0-logloss:0.41194
# [267]	validation_0-logloss:0.41131
# [268]	validation_0-logloss:0.41089
# [269]	validation_0-logloss:0.41044
# [270]	validation_0-logloss:0.40996
# [271]	validation_0-logloss:0.40953
# [272]	validation_0-logloss:0.40902
# [273]	validation_0-logloss:0.40879
# [274]	validation_0-logloss:0.40831
# [275]	validation_0-logloss:0.40788
# [276]	validation_0-logloss:0.40765
# [277]	validation_0-logloss:0.40719
# [278]	validation_0-logloss:0.40677
# [279]	validation_0-logloss:0.40650
# [280]	validation_0-logloss:0.40639
# [281]	validation_0-logloss:0.40598
# [282]	validation_0-logloss:0.40549
# [283]	validation_0-logloss:0.40503
# [284]	validation_0-logloss:0.40463
# [285]	validation_0-logloss:0.40441
# [286]	validation_0-logloss:0.40395
# [287]	validation_0-logloss:0.40355
# [288]	validation_0-logloss:0.40329
# [289]	validation_0-logloss:0.40317
# [290]	validation_0-logloss:0.40258
# [291]	validation_0-logloss:0.40219
# [292]	validation_0-logloss:0.40155
# [293]	validation_0-logloss:0.40133
# [294]	validation_0-logloss:0.40112
# [295]	validation_0-logloss:0.40073
# [296]	validation_0-logloss:0.40029
# [297]	validation_0-logloss:0.40007
# [298]	validation_0-logloss:0.39970
# [299]	validation_0-logloss:0.39908
# [300]	validation_0-logloss:0.39846
# [301]	validation_0-logloss:0.39835
# [302]	validation_0-logloss:0.39791
# [303]	validation_0-logloss:0.39754
# [304]	validation_0-logloss:0.39728
# [305]	validation_0-logloss:0.39693
# [306]	validation_0-logloss:0.39671
# [307]	validation_0-logloss:0.39611
# [308]	validation_0-logloss:0.39592
# [309]	validation_0-logloss:0.39568
# [310]	validation_0-logloss:0.39521
# [311]	validation_0-logloss:0.39478
# [312]	validation_0-logloss:0.39442
# [313]	validation_0-logloss:0.39383
# [314]	validation_0-logloss:0.39338
# [315]	validation_0-logloss:0.39295
# [316]	validation_0-logloss:0.39275
# [317]	validation_0-logloss:0.39217
# [318]	validation_0-logloss:0.39175
# [319]	validation_0-logloss:0.39118
# [320]	validation_0-logloss:0.39099
# [321]	validation_0-logloss:0.39054
# [322]	validation_0-logloss:0.39013
# [323]	validation_0-logloss:0.38957
# [324]	validation_0-logloss:0.38922
# [325]	validation_0-logloss:0.38882
# [326]	validation_0-logloss:0.38865
# [327]	validation_0-logloss:0.38821
# [328]	validation_0-logloss:0.38766
# [329]	validation_0-logloss:0.38742
# [330]	validation_0-logloss:0.38689
# [331]	validation_0-logloss:0.38667
# [332]	validation_0-logloss:0.38625
# [333]	validation_0-logloss:0.38591
# [334]	validation_0-logloss:0.38550
# [335]	validation_0-logloss:0.38532
# [336]	validation_0-logloss:0.38478
# [337]	validation_0-logloss:0.38437
# [338]	validation_0-logloss:0.38396
# [339]	validation_0-logloss:0.38344
# [340]	validation_0-logloss:0.38320
# [341]	validation_0-logloss:0.38299
# [342]	validation_0-logloss:0.38267
# [343]	validation_0-logloss:0.38227
# [344]	validation_0-logloss:0.38175
# [345]	validation_0-logloss:0.38155
# [346]	validation_0-logloss:0.38115
# [347]	validation_0-logloss:0.38083
# [348]	validation_0-logloss:0.38043
# [349]	validation_0-logloss:0.37951
# [350]	validation_0-logloss:0.37932
# [351]	validation_0-logloss:0.37901
# [352]	validation_0-logloss:0.37852
# [353]	validation_0-logloss:0.37829
# [354]	validation_0-logloss:0.37811
# [355]	validation_0-logloss:0.37781
# [356]	validation_0-logloss:0.37691
# [357]	validation_0-logloss:0.37642
# [358]	validation_0-logloss:0.37621
# [359]	validation_0-logloss:0.37583
# [360]	validation_0-logloss:0.37529
# [361]	validation_0-logloss:0.37499
# [362]	validation_0-logloss:0.37478
# [363]	validation_0-logloss:0.37424
# [364]	validation_0-logloss:0.37395
# [365]	validation_0-logloss:0.37357
# [366]	validation_0-logloss:0.37272
# [367]	validation_0-logloss:0.37254
# [368]	validation_0-logloss:0.37226
# [369]	validation_0-logloss:0.37180
# [370]	validation_0-logloss:0.37129
# [371]	validation_0-logloss:0.37100
# [372]	validation_0-logloss:0.37064
# [373]	validation_0-logloss:0.37047
# [374]	validation_0-logloss:0.36996
# [375]	validation_0-logloss:0.36968
# [376]	validation_0-logloss:0.36900
# [377]	validation_0-logloss:0.36850
# [378]	validation_0-logloss:0.36830
# [379]	validation_0-logloss:0.36763
# [380]	validation_0-logloss:0.36714
# [381]	validation_0-logloss:0.36688
# [382]	validation_0-logloss:0.36622
# [383]	validation_0-logloss:0.36574
# [384]	validation_0-logloss:0.36547
# [385]	validation_0-logloss:0.36500
# [386]	validation_0-logloss:0.36469
# [387]	validation_0-logloss:0.36456
# [388]	validation_0-logloss:0.36424
# [389]	validation_0-logloss:0.36397
# [390]	validation_0-logloss:0.36351
# [391]	validation_0-logloss:0.36324
# [392]	validation_0-logloss:0.36309
# [393]	validation_0-logloss:0.36288
# [394]	validation_0-logloss:0.36257
# [395]	validation_0-logloss:0.36212
# [396]	validation_0-logloss:0.36183
# [397]	validation_0-logloss:0.36162
# [398]	validation_0-logloss:0.36147
# [399]	validation_0-logloss:0.36118
# GridSearchCV(cv=3,
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None, gamma=None,
#                                      gpu_id=None, importance_type='gain',
#                                      interaction_constraints=None,
#                                      learning_rate=0.1, max_delta_step=None,
#                                      max_depth=3, min_child_weight=None,
#                                      missing=nan, monotone_constraints=None,
#                                      n_estimators=400, n_jobs=None,
#                                      num_parallel_tree=None, random_state=None,
#                                      reg_alpha=None, reg_lambda=None,
#                                      scale_pos_weight=None, subsample=None,
#                                      tree_method=None, validate_parameters=None,
#                                      verbosity=None),
#              param_grid={'learning_rate': [0.01, 0.05, 0.1],
#                          'n_estimators': [100, 200, 300, 400]},
#              scoring='recall')

# %%
# GridSearchCV 결과
score_df = pd.DataFrame(grid_cv.cv_results_)
score_df[['params','mean_test_score','rank_test_score','split0_test_score']].sort_values('rank_test_score').head()
# Out:
#                                          params  mean_test_score  \
# 3  {'learning_rate': 0.01, 'n_estimators': 400}         0.941358
# 0  {'learning_rate': 0.01, 'n_estimators': 100}         0.940844
# 4  {'learning_rate': 0.05, 'n_estimators': 100}         0.939558
# 1  {'learning_rate': 0.01, 'n_estimators': 200}         0.937243
# 2  {'learning_rate': 0.01, 'n_estimators': 300}         0.935957
#
#    rank_test_score  split0_test_score
# 3                1           0.912037
# 0                2           0.925154
# 4                3           0.909722
# 1                4           0.920525
# 2                5           0.917438

# %%
print('grid_cv.best_params_ :',grid_cv.best_params_)
print("grid_cv.best_score_ :",grid_cv.best_score_)
# Out:
# grid_cv.best_params_ : {'learning_rate': 0.01, 'n_estimators': 400}
# grid_cv.best_score_ : 0.941358024691358

# %%
# 최고 성능 파라미터와 추정기 불러오기
best_est = grid_cv.best_estimator_
best_param = grid_cv.best_params_
best_param
# Out:
# {'learning_rate': 0.01, 'n_estimators': 400}

# %%
# train data Evalutation
best_train_pred = best_est.predict(X_smote)
print('X_train ACC :',np.round(accuracy_score(best_train_pred,y_smote),4),'\n')
get_clf_eval(y_smote,best_train_pred)
# Out:
# X_train ACC : 0.8731
#
# [[3099  789]
#  [ 198 3690]]
# 정확도 :0.8731, 정밀도 :0.8238, 재현율 :0.9491, F1 :0.8820

# %%
# test data Evalutation
best_test_pred = best_est.predict(X_test)
print('X_test ACC :',np.round(accuracy_score(best_test_pred,y_test),4),'\n')
get_clf_eval(y_test,best_test_pred)
# Out:
# X_test ACC : 0.7798
#
# [[761 211]
#  [ 14  36]]
# 정확도 :0.7798, 정밀도 :0.1457, 재현율 :0.7200, F1 :0.2424

# %% [markdown]
# ## 6. Precision & Recall TradeOff

# %%
best_train_proba = best_est.predict_proba(X_smote)
best_train_proba_1 = best_train_proba[:,1]

best_test_proba = best_est.predict_proba(X_test)
best_test_proba_1 = best_test_proba[:,1]

# %%
roc_curve_plot(y_smote, best_train_proba_1)

# %%
roc_curve_plot(y_test, best_test_proba_1)

# %%
precision_recall_curve_plot(y_smote,best_train_proba_1)

# %%
precision_recall_curve_plot(y_test,best_test_proba_1)

# %% [markdown]
# ## 7. 사후 튜닝

# %%
after_pred = (best_test_proba[:,1] > 0.27)*1
after_pred
# Out:
# array([0, 0, 1, ..., 0, 0, 0])

# %%
get_clf_eval(y_test,after_pred)
# Out:
# [[581 391]
#  [  8  42]]
# 정확도 :0.6096, 정밀도 :0.0970, 재현율 :0.8400, F1 :0.1739

# %%
after_pred = (best_test_proba[:,1] > 0.07)*1
after_pred
# Out:
# array([0, 0, 1, ..., 0, 0, 1])

# %%
get_clf_eval(y_test,after_pred)
# Out:
# [[489 483]
#  [  7  43]]
# 정확도 :0.5205, 정밀도 :0.0817, 재현율 :0.8600, F1 :0.1493

# %% [markdown]
# ## 8. 모델 분석

# %%
# 피처의 중요도를 추출하기
best_est.feature_importances_
# Out:
# array([0.04024078, 0.3940084 , 0.03207024, 0.06284753, 0.03134374,
#        0.06056589, 0.08162604, 0.01958949, 0.15117972, 0.12652816],
#       dtype=float32)

# %%
# 피처의 중요도 시각화 하기
plt.title('DT Feature Importances')
sns.barplot(x = best_est.feature_importances_, y = df.columns.difference(['stroke']))
plt.show()
